# %%
import torch
import numpy as np
from itertools import product, chain
from torch import nn
import torch.nn.functional as F
import argparse

# %%
class LearntNeighbourhoodSampling(nn.Module):

    def __init__(self, config, features_count, step):
        super(LearntNeighbourhoodSampling, self).__init__()

        D, H, W = config.patch_shape 
        self.shape = torch.tensor([W, H, D]).cuda().float()

        self.shift = torch.tensor(list(product((-1, 0, 1), repeat=3)))[None].float() * torch.tensor([[[2 ** (config.steps+1 - step)/(W), 2 ** (config.steps+1 - step)/(H), 2 ** (config.steps+1 - step)/(D)]]])[None]
        self.shift = self.shift.cuda()

        self.sum_neighbourhood = nn.Conv2d(features_count, features_count, kernel_size=(1, 27), padding=0).cuda()

        # torch.nn.init.kaiming_normal_(self.sum_neighbourhood.weight, nonlinearity='relu')
        # torch.nn.init.constant_(self.sum_neighbourhood.bias, 0)
        self.shift_delta = nn.Conv1d(features_count, 27*3, kernel_size=(1), padding=0).cuda()
        self.shift_delta.weight.data.fill_(0.0)
        self.shift_delta.bias.data.fill_(0.0)

        self.feature_diff_1 = nn.Linear(features_count + 3, features_count)
        self.feature_diff_2 = nn.Linear(features_count, features_count) 

        self.feature_center_1 = nn.Linear(features_count + 3, features_count)
        self.feature_center_2 = nn.Linear(features_count, features_count)

    def forward(self, voxel_features, vertices):

        B, N, _ = vertices.shape
        center = vertices[:, :, None, None]
        features = F.grid_sample(voxel_features, center, mode='bilinear', padding_mode='border', align_corners=True)
        features = features[:, :, :, 0, 0]
        shift_delta = self.shift_delta(features).permute(0, 2, 1).view(B, N, 27, 1, 3)
        shift_delta[:,:,0,:,:] = shift_delta[:,:,0,:,:] * 0 # setting first shift to zero so it samples at the exact point
 
        # neighbourhood = vertices[:, :, None, None] + self.shift[:, :, :, None] + shift_delta
        neighbourhood = vertices[:, :, None, None] + shift_delta
        features = F.grid_sample(voxel_features, neighbourhood, mode='bilinear', padding_mode='border', align_corners=True)
        features = features[:, :, :, :, 0]
        features = torch.cat([features, neighbourhood.permute(0,4,1,2,3)[:,:,:,:,0]], dim=1)

        features_diff_from_center = features - features[:,:,:,0][:,:,:,None] # 0 is the index of the center cordinate in shifts
        features_diff_from_center = features_diff_from_center.permute([0,3,2,1])
        features_diff_from_center = self.feature_diff_1(features_diff_from_center)
        features_diff_from_center = self.feature_diff_2(features_diff_from_center)
        features_diff_from_center = features_diff_from_center.permute([0,3,2,1])
        
        features_diff_from_center = self.sum_neighbourhood(features_diff_from_center)[:, :, :, 0].transpose(2, 1)

        center_feautres =  features[:,:,:,13].transpose(2, 1)
        center_feautres = self.feature_center_1(center_feautres)
        center_feautres = self.feature_center_2(center_feautres)

        features = center_feautres + features_diff_from_center 
        return features
    
class GraphConv(nn.Module):
    __constants__ = ['bias', 'in_features', 'out_features']

    def __init__(self, in_features, out_features, batch_norm=False):
        super(GraphConv, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.fc = nn.Linear(in_features, out_features)
        self.neighbours_fc = nn.Linear(in_features, out_features)

        self.bc = nn.BatchNorm1d(out_features) if batch_norm else Non()

    def forward(self, input, A, Dinv, vertices, faces):
        # coeff = torch.bmm(torch.bmm(Dsqrtinv, A), Dsqrtinv)
        coeff = torch.bmm(Dinv, A) # row normalization 

        y = self.fc(input)
        y_neightbours = torch.bmm(coeff, input)
        y_neightbours = self.neighbours_fc(y_neightbours)
 
 
        # y_neightbours = self.bc(y_neightbours.permute(0, 2, 1)).permute(0, 2, 1)
        y = y + y_neightbours
        # y = self.bc(y.permute(0, 2, 1)).permute(0, 2, 1)
        return y

    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(
            self.in_features, self.out_features is not None
        )
    
class Feature2VertexLayer(nn.Module):

    def __init__(self, in_features, hidden_layer_count, batch_norm=False):
        super(Feature2VertexLayer, self).__init__()
        self.gconv = []
        for i in range(hidden_layer_count, 1, -1):
            self.gconv += [GraphConv(i * in_features // hidden_layer_count, (i-1) * in_features // hidden_layer_count, batch_norm)]
        self.gconv_layer = nn.Sequential(*self.gconv)
        self.gconv_last = GraphConv(in_features // hidden_layer_count, 3, batch_norm)

    def forward(self, features, adjacency_matrix, degree_matrix, vertices, faces):
        for gconv_hidden in self.gconv:
            features = F.relu(gconv_hidden(features, adjacency_matrix, degree_matrix,vertices,faces))
        return self.gconv_last(features, adjacency_matrix, degree_matrix,vertices,faces)

class Features2Features(nn.Module):

    def __init__(self, in_features, out_features, hidden_layer_count=2, graph_conv=GraphConv):
        super(Features2Features, self).__init__()

        self.gconv_first = graph_conv(in_features, out_features)
        gconv_hidden = []
        for i in range(hidden_layer_count):
            gconv_hidden += [graph_conv(out_features, out_features)]
        self.gconv_hidden = nn.Sequential(*gconv_hidden)
        self.gconv_last = graph_conv(out_features, out_features)

    def forward(self, features, adjacency_matrix, degree_matrix, vertices, faces):
        features = F.relu(self.gconv_first(features, adjacency_matrix, degree_matrix, vertices,faces))
        for gconv_hidden in self.gconv_hidden:
            features = F.relu(gconv_hidden(features, adjacency_matrix, degree_matrix, vertices,faces))
        return self.gconv_last(features, adjacency_matrix, degree_matrix, vertices, faces)

class UNetLayer(nn.Module):
    """ U-Net Layer """
    def __init__(self, num_channels_in, num_channels_out, ndims, batch_norm=False):

        super(UNetLayer, self).__init__()

        conv_op = nn.Conv2d if ndims == 2 else nn.Conv3d
        batch_nrom_op = nn.BatchNorm2d if ndims == 2 else nn.BatchNorm3d

        conv1 = conv_op(num_channels_in,  num_channels_out, kernel_size=3, padding=1)
        conv2 = conv_op(num_channels_out, num_channels_out, kernel_size=3, padding=1)

        bn1 = batch_nrom_op(num_channels_out)
        bn2 = batch_nrom_op(num_channels_out)
        self.unet_layer = nn.Sequential(conv1, bn1, nn.ReLU(), conv2, bn2, nn.ReLU())

    def forward(self, x):
        return self.unet_layer(x)

# %%
config = argparse.Namespace(
    batch_size=1,
    ndims=3,
    num_classes=5,
    first_layer_channels=64,
    steps=3,
    graph_conv_layer_count=2,
    batch_norm=True,
    patch_shape = (32, 32, 32)
    # Dodaj inne parametry w razie potrzeby
)

# %%
class V2M_Decoder(nn.Module):

    def __init__(self, config):
        
        super(V2M_Decoder, self).__init__()

        self.config = config
        self.max_pool = nn.MaxPool3d(2) if config.ndims == 3 else nn.MaxPool2d(2) 

        ConvTransposeLayer = nn.ConvTranspose3d #if config.ndims == 3, ale u nas zawsze mamy 3D, nie operujemy na płaskich meshach (?)


        ''' Up layers ''' 
        self.skip_count = []
        self.latent_features_coount = []
        for i in range(config.steps+1):
            self.skip_count += [config.first_layer_channels * 2 ** (config.steps-i)] 
            self.latent_features_coount += [32]

        dim = 3

        up_std_conv_layers = []
        up_f2f_layers = []
        up_f2v_layers = []
        for i in range(config.steps+1):
            graph_unet_layers = []
            feature2vertex_layers = []
            skip = LearntNeighbourhoodSampling(config, self.skip_count[i], i)
            # lyr = Feature2VertexLayer(self.skip_count[i])
            if i == 0:
                grid_upconv_layer = None
                grid_unet_layer = None
                for k in range(config.num_classes-1):
                    graph_unet_layers += [Features2Features(self.skip_count[i] + dim, self.latent_features_coount[i], hidden_layer_count=config.graph_conv_layer_count)] # , graph_conv=GraphConv
            else:
                grid_upconv_layer = ConvTransposeLayer(in_channels=config.first_layer_channels   * 2**(config.steps - i+1), out_channels=config.first_layer_channels * 2**(config.steps-i), kernel_size=2, stride=2)
                grid_unet_layer = UNetLayer(config.first_layer_channels * 2**(config.steps - i + 1), config.first_layer_channels * 2**(config.steps-i), config.ndims, config.batch_norm)
                for k in range(config.num_classes-1):
                    graph_unet_layers += [Features2Features(self.skip_count[i] + self.latent_features_coount[i-1] + dim, self.latent_features_coount[i], hidden_layer_count=config.graph_conv_layer_count)] #, graph_conv=GraphConv if i < config.steps else GraphConvNoNeighbours
            for k in range(config.num_classes-1):
                feature2vertex_layers += [Feature2VertexLayer(self.latent_features_coount[i], 3)] 

            up_std_conv_layers.append((skip, grid_upconv_layer, grid_unet_layer))
            up_f2f_layers.append(graph_unet_layers)
            up_f2v_layers.append(feature2vertex_layers)

        self.up_std_conv_layers = up_std_conv_layers
        self.up_f2f_layers = up_f2f_layers
        self.up_f2v_layers = up_f2v_layers

        self.decoder_std_conv = nn.Sequential(*chain(*up_std_conv_layers))
        self.decoder_f2f = nn.Sequential(*chain(*up_f2f_layers))
        self.decoder_f2v = nn.Sequential(*chain(*up_f2v_layers))

    def forward(self, x):
        # Wejście x to już cechy obiektu, przekazujemy je przez dekoder
        x = self.decoder_std_conv(x)
        x = self.decoder_f2f(x)
        x = self.decoder_f2v(x)
        return x

# %%
# Inicjalizuj model z podaną konfiguracją
model = V2M_Decoder(config)

# Przykładowe dane wejściowe
input_features = torch.rand((config.batch_size, config.first_layer_channels, config.ndims))

# Przetestuj propagację przez model
output = model.forward(input_features)

# Wypisz wynik
print("Wynik propagacji przez model:")
print(output)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Inicjalizuj model z podaną konfiguracją
# ----> <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> model = V2M_Decoder(config)
#       <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> # Przykładowe dane wejściowe
#       <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> input_features = torch.rand((config.batch_size, config.first_layer_channels, config.ndims))
#
# /home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a> graph_unet_layers = []
#      <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a> feature2vertex_layers = []
# ---> <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> skip = LearntNeighbourhoodSampling(config, self.skip_count[i], i)
#      <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=28'>29</a> # lyr = Feature2VertexLayer(self.skip_count[i])
#      <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a> if i == 0:
#
# /home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb Cell 5 line 7
#       <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> super(LearntNeighbourhoodSampling, self).__init__()
#       <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> D, H, W = config.patch_shape
# ----> <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> self.shape = torch.tensor([W, H, D]).cuda().float()
#       <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> self.shift = torch.tensor(list(product((-1, 0, 1), repeat=3)))[None].float() * torch.tensor([[[2 ** (config.steps+1 - step)/(W), 2 ** (config.steps+1 - step)/(H), 2 ** (config.steps+1 - step)/(D)]]])[None]
#      <a href='vscode-notebook-cell:/home/ppjotrek/Python/MeshProcTesting/architecture_test.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> self.shift = self.shift.cuda()
#
# File ~/Python/MeshProcTesting/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:298, in _lazy_init()
#     296 if "CUDA_MODULE_LOADING" not in os.environ:
#     297     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 298 torch._C._cuda_init()
#     299 # Some of the queued calls may reentrantly call _lazy_init();
#     300 # we need to just return without initializing in that case.
#     301 # However, we must not let any *other* threads in!
#     302 _tls.is_initializing = True
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class MeshDeformationEncoder(nn.Module):
    def __init__(self, num_vertices, num_faces, input_size):
        super(MeshDeformationEncoder, self).__init__()
        self.embedding_layer = nn.Linear(input_size, 256)
        self.fc1 = nn.Linear(256, 512)
        self.fc2 = nn.Linear(512, 1024)
        self.fc3 = nn.Linear(1024, num_vertices * 3)  # 3 współrzędne na wierzchołek

    def forward(self, vertices, faces, latent_features):
        x = F.relu(self.embedding_layer(latent_features))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        decoded_vertices = self.fc3(x)
        decoded_vertices = decoded_vertices.view(decoded_vertices.size(0), -1, 3)
        decoded_vertices = F.normalize(decoded_vertices, p=2, dim=2) #nie wiem czy potrzebuję normalizować, i czy to nie zaszkodzi bardziej szczerze mówiąc
        num_vertices_decoded = decoded_vertices.size(1)
        decoded_vertices = decoded_vertices.view(1, num_vertices_decoded, 3)

        print("original vertices size:", vertices.size())
        print("new vertices size:", decoded_vertices.size())
        deformed_vertices = decoded_vertices

        return deformed_vertices

# %%
import numpy as np
from stl import mesh

loaded_mesh = mesh.Mesh.from_file('Sphere.stl')
vertex_dict = {} #for storing vertices and their indices, helps to avoid duplicating the same vertices
vertices = np.empty((0, 3), dtype=float) #array of vertices - shape (n, 3), stores x, y, z coordinates of each vertex
faces = [] #array of faces - shape (n, 3), stores indices of vertices in each face

for vectors in loaded_mesh.vectors:
        for vertex in vectors:
            vertex_tuple = tuple(vertex)

            if vertex_tuple in vertex_dict:
                index = vertex_dict[vertex_tuple]
            else:
                index = len(vertices)
                vertices = np.append(vertices, [vertex], axis=0)
                vertex_dict[vertex_tuple] = index

        faces.append([vertex_dict[tuple(vertex)] for vertex in vectors])

# %%
input_size = 500

# Załaduj dane latentne (przykładowe dane, zastąp je własnymi)
latent_features = torch.randn(1, input_size)

# Wygeneruj przykładową tablicę wierzchołków reprezentującą sferę
num_vertices = 256  # Dla przykładu używam 256 wierzchołków

sphere_vertices, faces = torch.tensor(vertices), torch.tensor(faces)

faces = torch.tensor(faces, dtype=torch.long).view(1, -1, 3)
num_faces = (num_vertices - 1) * (num_vertices - 1) * 2

# Utwórz instancję enkodera
encoder = MeshDeformationEncoder(num_vertices, num_faces, input_size)

# Ustaw model w tryb ewaluacji (bez trenowania)
encoder.eval()

# Uzyskaj zdeformowane współrzędne wierzchołków i ścian
with torch.no_grad():
    deformed_vertices = encoder(sphere_vertices, faces, latent_features)

print("Oryginalne wierzchołki sfery:")
print(sphere_vertices)

print("\nIndeksy ścian:")
print(faces)

print("\nZdeformowane współrzędne wierzchołków:")
print(deformed_vertices)
# Out:
# original vertices size: torch.Size([1250, 3])
# new vertices size: torch.Size([1, 256, 3])
# Oryginalne wierzchołki sfery:
# tensor([[  3.1148,   0.3935,  49.9013],
#         [  3.1148,  -0.3935,  49.9013],
#         [  3.1395,   0.0000,  49.9013],
#         ...,
#         [  2.9191,  -1.1557, -49.9013],
#         [  3.0409,  -0.7808, -49.9013],
#         [  3.1148,  -0.3935, -49.9013]], dtype=torch.float64)
#
# Indeksy ścian:
# tensor([[[   0,    1,    2],
#          [   3,    1,    0],
#          [   3,    4,    1],
#          ...,
#          [1226, 1223, 1227],
#          [1226, 1224, 1223],
#          [1224, 1226, 1225]]])
#
# Zdeformowane współrzędne wierzchołków:
# tensor([[[-1.7938e-01,  5.7605e-01,  7.9749e-01],
#          [ 6.6789e-01,  7.3533e-01,  1.1495e-01],
#          [ 5.1060e-02, -7.6379e-01, -6.4344e-01],
#          [-5.8193e-01, -7.4212e-01, -3.3259e-01],
#          [-9.1538e-01,  3.3410e-01,  2.2463e-01],
#          [ 6.3569e-01, -1.6621e-01, -7.5384e-01],
#          [-9.6677e-01, -3.1371e-02, -2.5372e-01],
#          [-2.3701e-01,  9.5737e-01, -1.6515e-01],
#          [-9.6359e-01,  2.6711e-01,  1.1986e-02],
#          [ 5.4789e-01,  8.3042e-01, -1.0107e-01],
#          [-9.7883e-02, -7.2821e-02, -9.9253e-01],
#          [-6.3192e-01,  3.5801e-01, -6.8739e-01],
#          [-4.4836e-01, -3.7977e-01,  8.0917e-01],
#          [-4.4060e-01, -8.9384e-01, -8.3248e-02],
#          [ 3.3460e-05, -9.7434e-01, -2.2507e-01],
#          [-4.1464e-01,  4.5115e-01, -7.9028e-01],
#          [-5.2998e-01, -8.0820e-01, -2.5679e-01],
#          [ 9.7380e-01, -3.1112e-02,  2.2528e-01],
#          [-6.6858e-01, -2.6374e-01,  6.9530e-01],
#          [ 7.0016e-01,  3.9643e-01,  5.9382e-01],
#          [ 8.3532e-01, -1.5102e-01, -5.2862e-01],
#          [ 9.1329e-01,  3.7765e-01,  1.5258e-01],
#          [ 8.4339e-01, -3.0277e-01,  4.4388e-01],
#          [-6.4557e-01,  3.0168e-01, -7.0159e-01],
#          [-8.8618e-01,  2.0138e-01,  4.1729e-01],
#          [ 1.8497e-01, -8.4186e-01, -5.0700e-01],
#          [ 1.2151e-01,  3.5357e-01, -9.2748e-01],
#          [-9.7789e-01,  1.6582e-01,  1.2739e-01],
#          [-1.1345e-02, -7.7885e-01, -6.2711e-01],
#          [ 4.0930e-01, -1.2640e-01,  9.0360e-01],
#          [ 9.8330e-01,  4.1855e-02, -1.7711e-01],
#          [-8.5457e-01,  2.1638e-01, -4.7212e-01],
#          [ 8.8524e-02, -3.3742e-01, -9.3718e-01],
#          [ 8.6841e-01, -3.9087e-01,  3.0508e-01],
#          [ 1.2474e-01,  1.5778e-01, -9.7956e-01],
#          [ 4.9656e-01,  3.8496e-01,  7.7796e-01],
#          [ 6.3631e-01, -7.7142e-01,  5.1911e-03],
#          [-2.2475e-01,  6.2968e-01, -7.4364e-01],
#          [ 6.7638e-01, -2.8850e-01, -6.7770e-01],
#          [-8.3878e-01,  4.8968e-01, -2.3803e-01],
#          [-8.7011e-01,  4.5544e-01,  1.8837e-01],
#          [ 3.5368e-01,  8.1162e-01, -4.6496e-01],
#          [ 2.4401e-01, -2.7677e-01,  9.2944e-01],
#          [ 6.2401e-01, -1.9138e-01, -7.5762e-01],
#          [ 6.1011e-01, -2.9740e-01, -7.3439e-01],
#          [-3.2649e-01,  2.7555e-01,  9.0414e-01],
#          [-9.4543e-01, -3.2265e-01,  4.5473e-02],
#          [ 9.2873e-01,  3.6086e-01, -8.5083e-02],
#          [-5.0050e-01,  3.2466e-01,  8.0256e-01],
#          [-8.1604e-01,  2.2904e-01, -5.3067e-01],
#          [-6.8146e-01,  6.7777e-01, -2.7611e-01],
#          [ 1.8555e-01, -5.2071e-01,  8.3333e-01],
#          [ 2.2236e-01,  7.3351e-01, -6.4227e-01],
#          [ 2.1549e-01, -1.9909e-01,  9.5599e-01],
#          [ 6.9314e-01, -6.9635e-01,  1.8616e-01],
#          [ 1.0150e-01,  1.8330e-01,  9.7780e-01],
#          [-4.1681e-01,  6.9420e-01, -5.8682e-01],
#          [ 6.4997e-02,  7.7241e-01, -6.3179e-01],
#          [-2.6529e-01, -6.6423e-01,  6.9887e-01],
#          [-6.6186e-01, -7.4345e-01,  9.5989e-02],
#          [ 5.6633e-01,  7.1938e-01,  4.0220e-01],
#          [-9.5371e-01, -2.5332e-01, -1.6205e-01],
#          [ 2.1048e-01, -7.7003e-01, -6.0229e-01],
#          [ 3.3078e-01,  7.4701e-02, -9.4075e-01],
#          [ 2.8074e-01, -7.9834e-01, -5.3277e-01],
#          [-4.9379e-01, -3.9305e-01,  7.7568e-01],
#          [ 5.1061e-01, -6.1039e-01, -6.0556e-01],
#          [-4.3898e-01,  3.5388e-02, -8.9780e-01],
#          [-3.3149e-01, -9.4156e-01, -5.9897e-02],
#          [-5.2932e-01, -6.0943e-01, -5.9027e-01],
#          [-8.4751e-01, -5.2743e-01,  5.9523e-02],
#          [ 9.7461e-01,  7.0348e-02,  2.1259e-01],
#          [ 8.3639e-01,  2.6548e-01, -4.7955e-01],
#          [ 7.8148e-01, -2.4626e-01,  5.7327e-01],
#          [-5.2613e-01, -1.3410e-01, -8.3976e-01],
#          [-3.7732e-01, -8.5669e-01,  3.5173e-01],
#          [ 6.4689e-02, -7.3819e-01, -6.7148e-01],
#          [-1.7122e-01,  7.0689e-01,  6.8628e-01],
#          [-1.4803e-01,  3.7755e-01,  9.1408e-01],
#          [-8.1939e-01, -1.5834e-01,  5.5093e-01],
#          [-1.5742e-01,  9.2225e-01,  3.5310e-01],
#          [ 5.2450e-01,  5.0533e-01,  6.8523e-01],
#          [ 6.1921e-01,  2.9394e-01, -7.2813e-01],
#          [-3.8554e-01,  8.8686e-01, -2.5462e-01],
#          [-9.8662e-01, -1.4114e-01, -8.1635e-02],
#          [-8.9500e-01,  4.4594e-02, -4.4384e-01],
#          [-4.3950e-01,  5.1488e-01,  7.3603e-01],
#          [-5.7301e-01,  1.6747e-01, -8.0226e-01],
#          [-4.5161e-01, -8.3196e-01, -3.2233e-01],
#          [-6.4363e-02, -9.7764e-01, -2.0020e-01],
#          [-9.8307e-01,  1.1237e-01,  1.4474e-01],
#          [-2.0335e-01, -9.7711e-01, -6.2559e-02],
#          [ 2.4861e-02,  9.6276e-01, -2.6922e-01],
#          [ 4.3403e-01, -3.2587e-01, -8.3990e-01],
#          [ 7.1912e-01, -6.8919e-01, -8.8729e-02],
#          [-3.4538e-01, -4.6909e-01,  8.1281e-01],
#          [-3.5883e-01, -1.5267e-01,  9.2083e-01],
#          [-5.3495e-01,  7.9850e-01, -2.7608e-01],
#          [-2.3158e-01,  3.2464e-01,  9.1705e-01],
#          [-1.4977e-01, -7.1861e-01,  6.7909e-01],
#          [-8.0805e-01,  5.5118e-01, -2.0800e-01],
#          [-7.5632e-01, -5.5260e-01, -3.5016e-01],
#          [ 9.1863e-01,  2.7066e-01,  2.8784e-01],
#          [-6.4632e-02,  5.8644e-01,  8.0741e-01],
#          [ 7.2197e-01, -6.7178e-01,  1.6575e-01],
#          [-9.9731e-01,  1.8116e-02, -7.1076e-02],
#          [-7.4894e-01, -4.6150e-01, -4.7551e-01],
#          [-1.2725e-01,  1.7039e-01, -9.7713e-01],
#          [-9.1565e-01, -2.6881e-01,  2.9889e-01],
#          [-2.3750e-01, -9.0113e-01, -3.6270e-01],
#          [ 2.8935e-01, -3.2061e-01, -9.0193e-01],
#          [-7.0702e-01, -7.0656e-01, -2.9948e-02],
#          [ 4.8100e-01, -8.3411e-01,  2.7000e-01],
#          [-8.4092e-01,  3.6100e-01,  4.0315e-01],
#          [-7.7794e-01,  2.8352e-01, -5.6074e-01],
#          [ 7.7687e-01, -5.5825e-01, -2.9127e-01],
#          [ 4.7972e-01, -2.4412e-01,  8.4278e-01],
#          [ 5.4522e-01,  7.0780e-01, -4.4916e-01],
#          [-8.0228e-01,  4.0154e-02,  5.9559e-01],
#          [ 6.5645e-01, -4.1921e-01, -6.2717e-01],
#          [-1.1606e-01, -4.3407e-01,  8.9337e-01],
#          [ 8.9346e-01,  7.3081e-02, -4.4316e-01],
#          [ 3.5801e-01,  9.1945e-01, -1.6261e-01],
#          [ 9.4126e-01,  1.5980e-01, -2.9749e-01],
#          [ 3.2967e-01,  3.7799e-01, -8.6513e-01],
#          [ 3.0898e-01, -9.4771e-01,  7.9870e-02],
#          [-6.3979e-01, -7.3616e-01,  2.2076e-01],
#          [ 2.9973e-01, -4.0511e-01,  8.6374e-01],
#          [ 7.9684e-01, -6.0376e-01,  2.2827e-02],
#          [ 5.8569e-01,  2.1221e-01,  7.8226e-01],
#          [-8.4598e-01,  6.4992e-02, -5.2924e-01],
#          [ 9.9081e-01,  1.3520e-01,  4.7051e-03],
#          [-1.9414e-01,  5.5486e-01,  8.0897e-01],
#          [-7.7906e-01, -6.5019e-02, -6.2356e-01],
#          [ 2.1515e-01,  9.2553e-01,  3.1161e-01],
#          [ 3.8027e-01, -4.9735e-01,  7.7977e-01],
#          [-9.7367e-01,  3.7451e-02,  2.2486e-01],
#          [ 1.8016e-01,  9.3048e-01, -3.1899e-01],
#          [-5.8608e-02, -2.3022e-01, -9.7137e-01],
#          [ 3.8710e-01, -9.0326e-01, -1.8514e-01],
#          [-8.0990e-01,  7.5547e-02, -5.8168e-01],
#          [ 3.5195e-01,  7.9905e-01, -4.8750e-01],
#          [-1.4704e-02, -6.6582e-01, -7.4597e-01],
#          [ 6.5626e-01,  7.4351e-01, -1.2854e-01],
#          [-5.3251e-01,  6.5500e-01, -5.3610e-01],
#          [ 7.6936e-01,  1.9427e-01, -6.0856e-01],
#          [-3.7968e-01,  9.2416e-01,  4.2104e-02],
#          [ 2.5866e-01,  1.5347e-01, -9.5370e-01],
#          [-3.8470e-01,  6.2263e-01, -6.8142e-01],
#          [ 6.4262e-01,  7.4410e-01,  1.8262e-01],
#          [-8.5300e-01,  3.3383e-01,  4.0117e-01],
#          [-5.8019e-01, -5.8227e-01, -5.6951e-01],
#          [-9.7624e-01, -1.1755e-01,  1.8206e-01],
#          [ 4.9915e-01,  7.2607e-01, -4.7294e-01],
#          [ 1.4086e-01,  9.7644e-01, -1.6349e-01],
#          [-2.4778e-01, -1.3000e-01,  9.6005e-01],
#          [ 1.8385e-01,  5.3166e-01, -8.2676e-01],
#          [ 1.1888e-01,  5.8701e-01,  8.0080e-01],
#          [-3.4862e-01,  7.1319e-01,  6.0813e-01],
#          [ 4.1552e-01,  8.8786e-01,  1.9759e-01],
#          [ 8.9250e-01,  3.1459e-01,  3.2322e-01],
#          [-9.5906e-01,  2.2214e-01,  1.7565e-01],
#          [-2.8309e-01, -9.5437e-01, -9.5073e-02],
#          [ 6.0292e-01, -7.9761e-01, -1.7500e-02],
#          [ 7.3293e-01,  5.1160e-01,  4.4842e-01],
#          [ 7.2209e-01,  5.1060e-01, -4.6676e-01],
#          [-9.2194e-01, -2.9788e-01, -2.4757e-01],
#          [ 3.5513e-01,  4.3333e-01,  8.2832e-01],
#          [-1.9082e-01,  8.7462e-01,  4.4567e-01],
#          [-9.4159e-01,  1.2632e-01, -3.1216e-01],
#          [-4.1392e-01, -3.8714e-01, -8.2389e-01],
#          [-4.9766e-01, -8.4326e-01, -2.0309e-01],
#          [-1.3675e-01, -8.2069e-01,  5.5477e-01],
#          [-1.5930e-01, -3.8195e-02,  9.8649e-01],
#          [ 6.7211e-01,  5.8659e-01, -4.5185e-01],
#          [-2.3834e-01,  4.6433e-01, -8.5299e-01],
#          [-7.3766e-01,  6.4731e-01, -1.9196e-01],
#          [-6.7787e-01,  6.8516e-01,  2.6655e-01],
#          [ 8.1953e-01,  5.7124e-01,  4.5324e-02],
#          [-3.6270e-01,  8.2470e-01, -4.3395e-01],
#          [-7.9751e-01, -5.6789e-01, -2.0366e-01],
#          [-8.8725e-01, -2.8092e-01,  3.6588e-01],
#          [-1.2536e-01,  9.7468e-01,  1.8516e-01],
#          [ 2.4057e-01,  9.0351e-01, -3.5468e-01],
#          [-3.1405e-01, -2.8406e-01,  9.0591e-01],
#          [ 4.0748e-01,  8.9403e-01,  1.8622e-01],
#          [-6.9678e-01, -2.4820e-01, -6.7298e-01],
#          [ 6.3084e-01, -2.0296e-01, -7.4889e-01],
#          [ 2.6874e-02, -9.6201e-01, -2.7169e-01],
#          [ 3.9743e-01, -8.0645e-01,  4.3781e-01],
#          [ 3.0336e-01,  9.5048e-01, -6.7524e-02],
#          [-8.8225e-01, -3.9419e-01,  2.5740e-01],
#          [-5.4766e-01, -3.9959e-01,  7.3511e-01],
#          [ 5.5158e-01, -7.6701e-01, -3.2782e-01],
#          [-8.8347e-01,  4.6776e-01,  2.6109e-02],
#          [ 8.5208e-01, -5.2149e-01, -4.4811e-02],
#          [ 3.8928e-02, -3.2603e-01,  9.4456e-01],
#          [ 5.5300e-01, -7.5715e-01,  3.4773e-01],
#          [-2.9698e-01, -4.6284e-01, -8.3521e-01],
#          [ 4.2324e-01, -8.9882e-01,  1.1401e-01],
#          [-4.4527e-01,  8.9081e-01, -9.0495e-02],
#          [-4.0267e-01,  5.2235e-01,  7.5167e-01],
#          [-4.8778e-01, -7.5040e-01,  4.4605e-01],
#          [ 5.3209e-01, -7.5201e-01, -3.8905e-01],
#          [-1.3343e-01, -9.8668e-01,  9.3069e-02],
#          [-4.4451e-01, -4.0807e-01,  7.9743e-01],
#          [-5.5313e-01, -7.2514e-01,  4.1015e-01],
#          [ 4.0103e-01,  8.5008e-01,  3.4137e-01],
#          [ 3.6510e-01, -9.1249e-01, -1.8453e-01],
#          [-1.8654e-01, -4.3661e-01, -8.8010e-01],
#          [-5.1113e-01,  5.3919e-01, -6.6935e-01],
#          [ 3.2053e-01,  3.4916e-01,  8.8054e-01],
#          [ 9.0981e-01, -3.0828e-01, -2.7785e-01],
#          [ 8.5967e-01, -2.8177e-02, -5.1007e-01],
#          [ 9.0035e-01,  1.4835e-01,  4.0910e-01],
#          [-4.8159e-01, -4.4844e-01,  7.5298e-01],
#          [-3.2962e-01,  9.1527e-01,  2.3157e-01],
#          [-3.8844e-01, -8.9175e-01,  2.3215e-01],
#          [ 1.8791e-01,  9.8167e-01, -3.1868e-02],
#          [ 8.7879e-01, -2.3261e-01, -4.1668e-01],
#          [ 6.6842e-01,  6.3405e-01,  3.8883e-01],
#          [-1.0892e-01, -9.9152e-01,  7.0848e-02],
#          [ 2.4947e-02,  3.0264e-01,  9.5278e-01],
#          [ 4.2675e-01,  4.3259e-01, -7.9420e-01],
#          [-1.0533e-01,  8.4882e-01, -5.1808e-01],
#          [ 6.7563e-01,  1.8666e-01,  7.1322e-01],
#          [-4.0648e-01,  6.4574e-01, -6.4638e-01],
#          [-9.0387e-01,  2.4108e-01, -3.5342e-01],
#          [-1.9106e-01, -8.8693e-01, -4.2055e-01],
#          [ 8.1324e-01,  2.2119e-01,  5.3826e-01],
#          [-4.8635e-01,  6.8180e-01, -5.4646e-01],
#          [ 2.3719e-01,  9.7143e-01,  7.5310e-03],
#          [-1.1253e-01, -3.7156e-01, -9.2156e-01],
#          [ 9.5666e-01,  2.7629e-01,  9.2057e-02],
#          [ 6.6176e-01,  7.3740e-01,  1.3535e-01],
#          [-1.7721e-01, -5.6937e-01, -8.0275e-01],
#          [ 7.4795e-01, -1.0245e-01, -6.5580e-01],
#          [-2.7850e-01, -1.9573e-01,  9.4028e-01],
#          [ 1.4903e-01, -2.5173e-01, -9.5625e-01],
#          [ 2.2190e-01, -5.7045e-01,  7.9079e-01],
#          [ 4.6512e-01, -5.0731e-01,  7.2547e-01],
#          [ 2.1988e-01, -5.6802e-01,  7.9310e-01],
#          [-3.6559e-01, -2.1151e-01, -9.0643e-01],
#          [ 3.3605e-01,  9.1037e-01, -2.4144e-01],
#          [ 4.7307e-01, -1.3282e-01, -8.7096e-01],
#          [-2.8448e-02,  2.0251e-01,  9.7887e-01],
#          [ 5.7311e-01,  8.1007e-03,  8.1944e-01],
#          [-9.7045e-01, -2.1978e-01,  9.9621e-02],
#          [ 9.6915e-01,  2.2688e-02,  2.4544e-01],
#          [-3.2305e-01,  6.6706e-01, -6.7132e-01],
#          [-3.8076e-01,  8.3945e-01,  3.8775e-01],
#          [-7.9610e-01, -3.3875e-01, -5.0147e-01],
#          [-8.4280e-01,  5.3821e-01,  3.2163e-03],
#          [-1.0318e-01, -9.9347e-01, -4.8648e-02],
#          [-6.3539e-02, -7.8368e-01, -6.1790e-01],
#          [ 2.5394e-02, -2.0203e-02,  9.9947e-01]]])
# /tmp/ipykernel_5620/420722339.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   faces = torch.tensor(faces, dtype=torch.long).view(1, -1, 3)

# %%
import numpy as np
from stl import mesh

def save_mesh_to_stl(deformed_vertices, faces, stl_filename):
    # Przygotuj obiekt STL
    mesh_data = mesh.Mesh(np.zeros(len(faces[0]), dtype=mesh.Mesh.dtype))

    for i in range(len(faces[0])):
        for j in range(3):
            print(faces[0][i][j])
            try:
                mesh_data.vectors[i][j] = deformed_vertices[0, faces[0][i][j], :]
            except IndexError:
                mesh_data.vectors[i][j] = deformed_vertices[0, 0, :]

    # Zapisz obiekt STL do pliku
    mesh_data.save(stl_filename)

save_mesh_to_stl(deformed_vertices, faces, "output_mesh.stl")
print("File saved!")
# Out:
# tensor(0)
# tensor(1)
# tensor(2)
# tensor(3)
# tensor(1)
# tensor(0)
# tensor(3)
# tensor(4)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(3)
# tensor(5)
# tensor(6)
# tensor(4)
# tensor(7)
# tensor(6)
# tensor(5)
# tensor(7)
# tensor(8)
# tensor(6)
# tensor(9)
# tensor(8)
# tensor(7)
# tensor(9)
# tensor(10)
# tensor(8)
# tensor(11)
# tensor(10)
# tensor(9)
# tensor(11)
# tensor(12)
# tensor(10)
# tensor(13)
# tensor(12)
# tensor(11)
# tensor(13)
# tensor(14)
# tensor(12)
# tensor(15)
# tensor(14)
# tensor(13)
# tensor(15)
# tensor(16)
# tensor(14)
# tensor(17)
# tensor(16)
# tensor(15)
# tensor(17)
# tensor(18)
# tensor(16)
# tensor(19)
# tensor(18)
# tensor(17)
# tensor(19)
# tensor(20)
# tensor(18)
# tensor(21)
# tensor(20)
# tensor(19)
# tensor(21)
# tensor(22)
# tensor(20)
# tensor(23)
# tensor(22)
# tensor(21)
# tensor(23)
# tensor(24)
# tensor(22)
# tensor(25)
# tensor(24)
# tensor(23)
# tensor(25)
# tensor(26)
# tensor(24)
# tensor(27)
# tensor(26)
# tensor(25)
# tensor(27)
# tensor(28)
# tensor(26)
# tensor(29)
# tensor(28)
# tensor(27)
# tensor(29)
# tensor(30)
# tensor(28)
# tensor(31)
# tensor(30)
# tensor(29)
# tensor(31)
# tensor(32)
# tensor(30)
# tensor(33)
# tensor(32)
# tensor(31)
# tensor(33)
# tensor(34)
# tensor(32)
# tensor(35)
# tensor(34)
# tensor(33)
# tensor(35)
# tensor(36)
# tensor(34)
# tensor(37)
# tensor(36)
# tensor(35)
# tensor(37)
# tensor(38)
# tensor(36)
# tensor(39)
# tensor(38)
# tensor(37)
# tensor(39)
# tensor(40)
# tensor(38)
# tensor(41)
# tensor(40)
# tensor(39)
# tensor(41)
# tensor(42)
# tensor(40)
# tensor(43)
# tensor(42)
# tensor(41)
# tensor(43)
# tensor(44)
# tensor(42)
# tensor(45)
# tensor(44)
# tensor(43)
# tensor(45)
# tensor(46)
# tensor(44)
# tensor(47)
# tensor(46)
# tensor(45)
# tensor(47)
# tensor(48)
# tensor(46)
# tensor(48)
# tensor(47)
# tensor(49)
# tensor(50)
# tensor(51)
# tensor(2)
# tensor(51)
# tensor(0)
# tensor(2)
# tensor(51)
# tensor(52)
# tensor(0)
# tensor(52)
# tensor(3)
# tensor(0)
# tensor(52)
# tensor(53)
# tensor(3)
# tensor(53)
# tensor(5)
# tensor(3)
# tensor(53)
# tensor(54)
# tensor(5)
# tensor(54)
# tensor(7)
# tensor(5)
# tensor(54)
# tensor(55)
# tensor(7)
# tensor(55)
# tensor(9)
# tensor(7)
# tensor(55)
# tensor(56)
# tensor(9)
# tensor(56)
# tensor(11)
# tensor(9)
# tensor(56)
# tensor(57)
# tensor(11)
# tensor(57)
# tensor(13)
# tensor(11)
# tensor(57)
# tensor(58)
# tensor(13)
# tensor(58)
# tensor(15)
# tensor(13)
# tensor(58)
# tensor(59)
# tensor(15)
# tensor(59)
# tensor(17)
# tensor(15)
# tensor(59)
# tensor(60)
# tensor(17)
# tensor(60)
# tensor(19)
# tensor(17)
# tensor(60)
# tensor(61)
# tensor(19)
# tensor(61)
# tensor(21)
# tensor(19)
# tensor(61)
# tensor(62)
# tensor(21)
# tensor(62)
# tensor(23)
# tensor(21)
# tensor(62)
# tensor(63)
# tensor(23)
# tensor(63)
# tensor(25)
# tensor(23)
# tensor(63)
# tensor(64)
# tensor(25)
# tensor(64)
# tensor(27)
# tensor(25)
# tensor(64)
# tensor(65)
# tensor(27)
# tensor(65)
# tensor(29)
# tensor(27)
# tensor(65)
# tensor(66)
# tensor(29)
# tensor(66)
# tensor(31)
# tensor(29)
# tensor(66)
# tensor(67)
# tensor(31)
# tensor(67)
# tensor(33)
# tensor(31)
# tensor(67)
# tensor(68)
# tensor(33)
# tensor(68)
# tensor(35)
# tensor(33)
# tensor(68)
# tensor(69)
# tensor(35)
# tensor(69)
# tensor(37)
# tensor(35)
# tensor(69)
# tensor(70)
# tensor(37)
# tensor(70)
# tensor(39)
# tensor(37)
# tensor(70)
# tensor(71)
# tensor(39)
# tensor(71)
# tensor(41)
# tensor(39)
# tensor(71)
# tensor(72)
# tensor(41)
# tensor(72)
# tensor(43)
# tensor(41)
# tensor(72)
# tensor(73)
# tensor(43)
# tensor(73)
# tensor(45)
# tensor(43)
# tensor(73)
# tensor(74)
# tensor(45)
# tensor(74)
# tensor(47)
# tensor(45)
# tensor(74)
# tensor(75)
# tensor(47)
# tensor(75)
# tensor(49)
# tensor(47)
# tensor(75)
# tensor(76)
# tensor(49)
# tensor(76)
# tensor(48)
# tensor(49)
# tensor(76)
# tensor(77)
# tensor(48)
# tensor(77)
# tensor(46)
# tensor(48)
# tensor(77)
# tensor(78)
# tensor(46)
# tensor(78)
# tensor(44)
# tensor(46)
# tensor(78)
# tensor(79)
# tensor(44)
# tensor(79)
# tensor(42)
# tensor(44)
# tensor(79)
# tensor(80)
# tensor(42)
# tensor(80)
# tensor(40)
# tensor(42)
# tensor(80)
# tensor(81)
# tensor(40)
# tensor(81)
# tensor(38)
# tensor(40)
# tensor(81)
# tensor(82)
# tensor(38)
# tensor(82)
# tensor(36)
# tensor(38)
# tensor(82)
# tensor(83)
# tensor(36)
# tensor(83)
# tensor(34)
# tensor(36)
# tensor(83)
# tensor(84)
# tensor(34)
# tensor(84)
# tensor(32)
# tensor(34)
# tensor(84)
# tensor(85)
# tensor(32)
# tensor(85)
# tensor(30)
# tensor(32)
# tensor(85)
# tensor(86)
# tensor(30)
# tensor(86)
# tensor(28)
# tensor(30)
# tensor(86)
# tensor(87)
# tensor(28)
# tensor(87)
# tensor(26)
# tensor(28)
# tensor(87)
# tensor(88)
# tensor(26)
# tensor(88)
# tensor(24)
# tensor(26)
# tensor(88)
# tensor(89)
# tensor(24)
# tensor(89)
# tensor(22)
# tensor(24)
# tensor(89)
# tensor(90)
# tensor(22)
# tensor(90)
# tensor(20)
# tensor(22)
# tensor(90)
# tensor(91)
# tensor(20)
# tensor(91)
# tensor(18)
# tensor(20)
# tensor(91)
# tensor(92)
# tensor(18)
# tensor(92)
# tensor(16)
# tensor(18)
# tensor(92)
# tensor(93)
# tensor(16)
# tensor(93)
# tensor(14)
# tensor(16)
# tensor(93)
# tensor(94)
# tensor(14)
# tensor(94)
# tensor(12)
# tensor(14)
# tensor(94)
# tensor(95)
# tensor(12)
# tensor(95)
# tensor(10)
# tensor(12)
# tensor(95)
# tensor(96)
# tensor(10)
# tensor(96)
# tensor(8)
# tensor(10)
# tensor(96)
# tensor(97)
# tensor(8)
# tensor(97)
# tensor(6)
# tensor(8)
# tensor(97)
# tensor(98)
# tensor(6)
# tensor(98)
# tensor(4)
# tensor(6)
# tensor(98)
# tensor(99)
# tensor(4)
# tensor(99)
# tensor(1)
# tensor(4)
# tensor(99)
# tensor(50)
# tensor(1)
# tensor(50)
# tensor(2)
# tensor(1)
# tensor(100)
# tensor(101)
# tensor(50)
# tensor(101)
# tensor(51)
# tensor(50)
# tensor(101)
# tensor(102)
# tensor(51)
# tensor(102)
# tensor(52)
# tensor(51)
# tensor(102)
# tensor(103)
# tensor(52)
# tensor(103)
# tensor(53)
# tensor(52)
# tensor(103)
# tensor(104)
# tensor(53)
# tensor(104)
# tensor(54)
# tensor(53)
# tensor(104)
# tensor(105)
# tensor(54)
# tensor(105)
# tensor(55)
# tensor(54)
# tensor(105)
# tensor(106)
# tensor(55)
# tensor(106)
# tensor(56)
# tensor(55)
# tensor(106)
# tensor(107)
# tensor(56)
# tensor(107)
# tensor(57)
# tensor(56)
# tensor(107)
# tensor(108)
# tensor(57)
# tensor(108)
# tensor(58)
# tensor(57)
# tensor(108)
# tensor(109)
# tensor(58)
# tensor(109)
# tensor(59)
# tensor(58)
# tensor(109)
# tensor(110)
# tensor(59)
# tensor(110)
# tensor(60)
# tensor(59)
# tensor(110)
# tensor(111)
# tensor(60)
# tensor(111)
# tensor(61)
# tensor(60)
# tensor(111)
# tensor(112)
# tensor(61)
# tensor(112)
# tensor(62)
# tensor(61)
# tensor(112)
# tensor(113)
# tensor(62)
# tensor(113)
# tensor(63)
# tensor(62)
# tensor(113)
# tensor(114)
# tensor(63)
# tensor(114)
# tensor(64)
# tensor(63)
# tensor(114)
# tensor(115)
# tensor(64)
# tensor(115)
# tensor(65)
# tensor(64)
# tensor(115)
# tensor(116)
# tensor(65)
# tensor(116)
# tensor(66)
# tensor(65)
# tensor(116)
# tensor(117)
# tensor(66)
# tensor(117)
# tensor(67)
# tensor(66)
# tensor(117)
# tensor(118)
# tensor(67)
# tensor(118)
# tensor(68)
# tensor(67)
# tensor(118)
# tensor(119)
# tensor(68)
# tensor(119)
# tensor(69)
# tensor(68)
# tensor(119)
# tensor(120)
# tensor(69)
# tensor(120)
# tensor(70)
# tensor(69)
# tensor(120)
# tensor(121)
# tensor(70)
# tensor(121)
# tensor(71)
# tensor(70)
# tensor(121)
# tensor(122)
# tensor(71)
# tensor(122)
# tensor(72)
# tensor(71)
# tensor(122)
# tensor(123)
# tensor(72)
# tensor(123)
# tensor(73)
# tensor(72)
# tensor(123)
# tensor(124)
# tensor(73)
# tensor(124)
# tensor(74)
# tensor(73)
# tensor(124)
# tensor(125)
# tensor(74)
# tensor(125)
# tensor(75)
# tensor(74)
# tensor(125)
# tensor(126)
# tensor(75)
# tensor(126)
# tensor(76)
# tensor(75)
# tensor(126)
# tensor(127)
# tensor(76)
# tensor(127)
# tensor(77)
# tensor(76)
# tensor(127)
# tensor(128)
# tensor(77)
# tensor(128)
# tensor(78)
# tensor(77)
# tensor(128)
# tensor(129)
# tensor(78)
# tensor(129)
# tensor(79)
# tensor(78)
# tensor(129)
# tensor(130)
# tensor(79)
# tensor(130)
# tensor(80)
# tensor(79)
# tensor(130)
# tensor(131)
# tensor(80)
# tensor(131)
# tensor(81)
# tensor(80)
# tensor(131)
# tensor(132)
# tensor(81)
# tensor(132)
# tensor(82)
# tensor(81)
# tensor(132)
# tensor(133)
# tensor(82)
# tensor(133)
# tensor(83)
# tensor(82)
# tensor(133)
# tensor(134)
# tensor(83)
# tensor(134)
# tensor(84)
# tensor(83)
# tensor(134)
# tensor(135)
# tensor(84)
# tensor(135)
# tensor(85)
# tensor(84)
# tensor(135)
# tensor(136)
# tensor(85)
# tensor(136)
# tensor(86)
# tensor(85)
# tensor(136)
# tensor(137)
# tensor(86)
# tensor(137)
# tensor(87)
# tensor(86)
# tensor(137)
# tensor(138)
# tensor(87)
# tensor(138)
# tensor(88)
# tensor(87)
# tensor(138)
# tensor(139)
# tensor(88)
# tensor(139)
# tensor(89)
# tensor(88)
# tensor(139)
# tensor(140)
# tensor(89)
# tensor(140)
# tensor(90)
# tensor(89)
# tensor(140)
# tensor(141)
# tensor(90)
# tensor(141)
# tensor(91)
# tensor(90)
# tensor(141)
# tensor(142)
# tensor(91)
# tensor(142)
# tensor(92)
# tensor(91)
# tensor(142)
# tensor(143)
# tensor(92)
# tensor(143)
# tensor(93)
# tensor(92)
# tensor(143)
# tensor(144)
# tensor(93)
# tensor(144)
# tensor(94)
# tensor(93)
# tensor(144)
# tensor(145)
# tensor(94)
# tensor(145)
# tensor(95)
# tensor(94)
# tensor(145)
# tensor(146)
# tensor(95)
# tensor(146)
# tensor(96)
# tensor(95)
# tensor(146)
# tensor(147)
# tensor(96)
# tensor(147)
# tensor(97)
# tensor(96)
# tensor(147)
# tensor(148)
# tensor(97)
# tensor(148)
# tensor(98)
# tensor(97)
# tensor(148)
# tensor(149)
# tensor(98)
# tensor(149)
# tensor(99)
# tensor(98)
# tensor(149)
# tensor(100)
# tensor(99)
# tensor(100)
# tensor(50)
# tensor(99)
# tensor(150)
# tensor(151)
# tensor(100)
# tensor(151)
# tensor(101)
# tensor(100)
# tensor(151)
# tensor(152)
# tensor(101)
# tensor(152)
# tensor(102)
# tensor(101)
# tensor(152)
# tensor(153)
# tensor(102)
# tensor(153)
# tensor(103)
# tensor(102)
# tensor(153)
# tensor(154)
# tensor(103)
# tensor(154)
# tensor(104)
# tensor(103)
# tensor(154)
# tensor(155)
# tensor(104)
# tensor(155)
# tensor(105)
# tensor(104)
# tensor(155)
# tensor(156)
# tensor(105)
# tensor(156)
# tensor(106)
# tensor(105)
# tensor(156)
# tensor(157)
# tensor(106)
# tensor(157)
# tensor(107)
# tensor(106)
# tensor(157)
# tensor(158)
# tensor(107)
# tensor(158)
# tensor(108)
# tensor(107)
# tensor(158)
# tensor(159)
# tensor(108)
# tensor(159)
# tensor(109)
# tensor(108)
# tensor(159)
# tensor(160)
# tensor(109)
# tensor(160)
# tensor(110)
# tensor(109)
# tensor(160)
# tensor(161)
# tensor(110)
# tensor(161)
# tensor(111)
# tensor(110)
# tensor(161)
# tensor(162)
# tensor(111)
# tensor(162)
# tensor(112)
# tensor(111)
# tensor(162)
# tensor(163)
# tensor(112)
# tensor(163)
# tensor(113)
# tensor(112)
# tensor(163)
# tensor(164)
# tensor(113)
# tensor(164)
# tensor(114)
# tensor(113)
# tensor(164)
# tensor(165)
# tensor(114)
# tensor(165)
# tensor(115)
# tensor(114)
# tensor(165)
# tensor(166)
# tensor(115)
# tensor(166)
# tensor(116)
# tensor(115)
# tensor(166)
# tensor(167)
# tensor(116)
# tensor(167)
# tensor(117)
# tensor(116)
# tensor(167)
# tensor(168)
# tensor(117)
# tensor(168)
# tensor(118)
# tensor(117)
# tensor(168)
# tensor(169)
# tensor(118)
# tensor(169)
# tensor(119)
# tensor(118)
# tensor(169)
# tensor(170)
# tensor(119)
# tensor(170)
# tensor(120)
# tensor(119)
# tensor(170)
# tensor(171)
# tensor(120)
# tensor(171)
# tensor(121)
# tensor(120)
# tensor(171)
# tensor(172)
# tensor(121)
# tensor(172)
# tensor(122)
# tensor(121)
# tensor(172)
# tensor(173)
# tensor(122)
# tensor(173)
# tensor(123)
# tensor(122)
# tensor(173)
# tensor(174)
# tensor(123)
# tensor(174)
# tensor(124)
# tensor(123)
# tensor(174)
# tensor(175)
# tensor(124)
# tensor(175)
# tensor(125)
# tensor(124)
# tensor(175)
# tensor(176)
# tensor(125)
# tensor(176)
# tensor(126)
# tensor(125)
# tensor(176)
# tensor(177)
# tensor(126)
# tensor(177)
# tensor(127)
# tensor(126)
# tensor(177)
# tensor(178)
# tensor(127)
# tensor(178)
# tensor(128)
# tensor(127)
# tensor(178)
# tensor(179)
# tensor(128)
# tensor(179)
# tensor(129)
# tensor(128)
# tensor(179)
# tensor(180)
# tensor(129)
# tensor(180)
# tensor(130)
# tensor(129)
# tensor(180)
# tensor(181)
# tensor(130)
# tensor(181)
# tensor(131)
# tensor(130)
# tensor(181)
# tensor(182)
# tensor(131)
# tensor(182)
# tensor(132)
# tensor(131)
# tensor(182)
# tensor(183)
# tensor(132)
# tensor(183)
# tensor(133)
# tensor(132)
# tensor(183)
# tensor(184)
# tensor(133)
# tensor(184)
# tensor(134)
# tensor(133)
# tensor(184)
# tensor(185)
# tensor(134)
# tensor(185)
# tensor(135)
# tensor(134)
# tensor(185)
# tensor(186)
# tensor(135)
# tensor(186)
# tensor(136)
# tensor(135)
# tensor(186)
# tensor(187)
# tensor(136)
# tensor(187)
# tensor(137)
# tensor(136)
# tensor(187)
# tensor(188)
# tensor(137)
# tensor(188)
# tensor(138)
# tensor(137)
# tensor(188)
# tensor(189)
# tensor(138)
# tensor(189)
# tensor(139)
# tensor(138)
# tensor(189)
# tensor(190)
# tensor(139)
# tensor(190)
# tensor(140)
# tensor(139)
# tensor(190)
# tensor(191)
# tensor(140)
# tensor(191)
# tensor(141)
# tensor(140)
# tensor(191)
# tensor(192)
# tensor(141)
# tensor(192)
# tensor(142)
# tensor(141)
# tensor(192)
# tensor(193)
# tensor(142)
# tensor(193)
# tensor(143)
# tensor(142)
# tensor(193)
# tensor(194)
# tensor(143)
# tensor(194)
# tensor(144)
# tensor(143)
# tensor(194)
# tensor(195)
# tensor(144)
# tensor(195)
# tensor(145)
# tensor(144)
# tensor(195)
# tensor(196)
# tensor(145)
# tensor(196)
# tensor(146)
# tensor(145)
# tensor(196)
# tensor(197)
# tensor(146)
# tensor(197)
# tensor(147)
# tensor(146)
# tensor(197)
# tensor(198)
# tensor(147)
# tensor(198)
# tensor(148)
# tensor(147)
# tensor(198)
# tensor(199)
# tensor(148)
# tensor(199)
# tensor(149)
# tensor(148)
# tensor(199)
# tensor(150)
# tensor(149)
# tensor(150)
# tensor(100)
# tensor(149)
# tensor(200)
# tensor(201)
# tensor(150)
# tensor(201)
# tensor(151)
# tensor(150)
# tensor(201)
# tensor(202)
# tensor(151)
# tensor(202)
# tensor(152)
# tensor(151)
# tensor(202)
# tensor(203)
# tensor(152)
# tensor(203)
# tensor(153)
# tensor(152)
# tensor(203)
# tensor(204)
# tensor(153)
# tensor(204)
# tensor(154)
# tensor(153)
# tensor(204)
# tensor(205)
# tensor(154)
# tensor(205)
# tensor(155)
# tensor(154)
# tensor(205)
# tensor(206)
# tensor(155)
# tensor(206)
# tensor(156)
# tensor(155)
# tensor(206)
# tensor(207)
# tensor(156)
# tensor(207)
# tensor(157)
# tensor(156)
# tensor(207)
# tensor(208)
# tensor(157)
# tensor(208)
# tensor(158)
# tensor(157)
# tensor(208)
# tensor(209)
# tensor(158)
# tensor(209)
# tensor(159)
# tensor(158)
# tensor(209)
# tensor(210)
# tensor(159)
# tensor(210)
# tensor(160)
# tensor(159)
# tensor(210)
# tensor(211)
# tensor(160)
# tensor(211)
# tensor(161)
# tensor(160)
# tensor(211)
# tensor(212)
# tensor(161)
# tensor(212)
# tensor(162)
# tensor(161)
# tensor(212)
# tensor(213)
# tensor(162)
# tensor(213)
# tensor(163)
# tensor(162)
# tensor(213)
# tensor(214)
# tensor(163)
# tensor(214)
# tensor(164)
# tensor(163)
# tensor(214)
# tensor(215)
# tensor(164)
# tensor(215)
# tensor(165)
# tensor(164)
# tensor(215)
# tensor(216)
# tensor(165)
# tensor(216)
# tensor(166)
# tensor(165)
# tensor(216)
# tensor(217)
# tensor(166)
# tensor(217)
# tensor(167)
# tensor(166)
# tensor(217)
# tensor(218)
# tensor(167)
# tensor(218)
# tensor(168)
# tensor(167)
# tensor(218)
# tensor(219)
# tensor(168)
# tensor(219)
# tensor(169)
# tensor(168)
# tensor(219)
# tensor(220)
# tensor(169)
# tensor(220)
# tensor(170)
# tensor(169)
# tensor(220)
# tensor(221)
# tensor(170)
# tensor(221)
# tensor(171)
# tensor(170)
# tensor(221)
# tensor(222)
# tensor(171)
# tensor(222)
# tensor(172)
# tensor(171)
# tensor(222)
# tensor(223)
# tensor(172)
# tensor(223)
# tensor(173)
# tensor(172)
# tensor(223)
# tensor(224)
# tensor(173)
# tensor(224)
# tensor(174)
# tensor(173)
# tensor(224)
# tensor(225)
# tensor(174)
# tensor(225)
# tensor(175)
# tensor(174)
# tensor(225)
# tensor(226)
# tensor(175)
# tensor(226)
# tensor(176)
# tensor(175)
# tensor(226)
# tensor(227)
# tensor(176)
# tensor(227)
# tensor(177)
# tensor(176)
# tensor(227)
# tensor(228)
# tensor(177)
# tensor(228)
# tensor(178)
# tensor(177)
# tensor(228)
# tensor(229)
# tensor(178)
# tensor(229)
# tensor(179)
# tensor(178)
# tensor(229)
# tensor(230)
# tensor(179)
# tensor(230)
# tensor(180)
# tensor(179)
# tensor(230)
# tensor(231)
# tensor(180)
# tensor(231)
# tensor(181)
# tensor(180)
# tensor(231)
# tensor(232)
# tensor(181)
# tensor(232)
# tensor(182)
# tensor(181)
# tensor(232)
# tensor(233)
# tensor(182)
# tensor(233)
# tensor(183)
# tensor(182)
# tensor(233)
# tensor(234)
# tensor(183)
# tensor(234)
# tensor(184)
# tensor(183)
# tensor(234)
# tensor(235)
# tensor(184)
# tensor(235)
# tensor(185)
# tensor(184)
# tensor(235)
# tensor(236)
# tensor(185)
# tensor(236)
# tensor(186)
# tensor(185)
# tensor(236)
# tensor(237)
# tensor(186)
# tensor(237)
# tensor(187)
# tensor(186)
# tensor(237)
# tensor(238)
# tensor(187)
# tensor(238)
# tensor(188)
# tensor(187)
# tensor(238)
# tensor(239)
# tensor(188)
# tensor(239)
# tensor(189)
# tensor(188)
# tensor(239)
# tensor(240)
# tensor(189)
# tensor(240)
# tensor(190)
# tensor(189)
# tensor(240)
# tensor(241)
# tensor(190)
# tensor(241)
# tensor(191)
# tensor(190)
# tensor(241)
# tensor(242)
# tensor(191)
# tensor(242)
# tensor(192)
# tensor(191)
# tensor(242)
# tensor(243)
# tensor(192)
# tensor(243)
# tensor(193)
# tensor(192)
# tensor(243)
# tensor(244)
# tensor(193)
# tensor(244)
# tensor(194)
# tensor(193)
# tensor(244)
# tensor(245)
# tensor(194)
# tensor(245)
# tensor(195)
# tensor(194)
# tensor(245)
# tensor(246)
# tensor(195)
# tensor(246)
# tensor(196)
# tensor(195)
# tensor(246)
# tensor(247)
# tensor(196)
# tensor(247)
# tensor(197)
# tensor(196)
# tensor(247)
# tensor(248)
# tensor(197)
# tensor(248)
# tensor(198)
# tensor(197)
# tensor(248)
# tensor(249)
# tensor(198)
# tensor(249)
# tensor(199)
# tensor(198)
# tensor(249)
# tensor(200)
# tensor(199)
# tensor(200)
# tensor(150)
# tensor(199)
# tensor(250)
# tensor(251)
# tensor(200)
# tensor(251)
# tensor(201)
# tensor(200)
# tensor(251)
# tensor(252)
# tensor(201)
# tensor(252)
# tensor(202)
# tensor(201)
# tensor(252)
# tensor(253)
# tensor(202)
# tensor(253)
# tensor(203)
# tensor(202)
# tensor(253)
# tensor(254)
# tensor(203)
# tensor(254)
# tensor(204)
# tensor(203)
# tensor(254)
# tensor(255)
# tensor(204)
# tensor(255)
# tensor(205)
# tensor(204)
# tensor(255)
# tensor(256)
# tensor(205)
# tensor(256)
# tensor(206)
# tensor(205)
# tensor(256)
# tensor(257)
# tensor(206)
# tensor(257)
# tensor(207)
# tensor(206)
# tensor(257)
# tensor(258)
# tensor(207)
# tensor(258)
# tensor(208)
# tensor(207)
# tensor(258)
# tensor(259)
# tensor(208)
# tensor(259)
# tensor(209)
# tensor(208)
# tensor(259)
# tensor(260)
# tensor(209)
# tensor(260)
# tensor(210)
# tensor(209)
# tensor(260)
# tensor(261)
# tensor(210)
# tensor(261)
# tensor(211)
# tensor(210)
# tensor(261)
# tensor(262)
# tensor(211)
# tensor(262)
# tensor(212)
# tensor(211)
# tensor(262)
# tensor(263)
# tensor(212)
# tensor(263)
# tensor(213)
# tensor(212)
# tensor(263)
# tensor(264)
# tensor(213)
# tensor(264)
# tensor(214)
# tensor(213)
# tensor(264)
# tensor(265)
# tensor(214)
# tensor(265)
# tensor(215)
# tensor(214)
# tensor(265)
# tensor(266)
# tensor(215)
# tensor(266)
# tensor(216)
# tensor(215)
# tensor(266)
# tensor(267)
# tensor(216)
# tensor(267)
# tensor(217)
# tensor(216)
# tensor(267)
# tensor(268)
# tensor(217)
# tensor(268)
# tensor(218)
# tensor(217)
# tensor(268)
# tensor(269)
# tensor(218)
# tensor(269)
# tensor(219)
# tensor(218)
# tensor(269)
# tensor(270)
# tensor(219)
# tensor(270)
# tensor(220)
# tensor(219)
# tensor(270)
# tensor(271)
# tensor(220)
# tensor(271)
# tensor(221)
# tensor(220)
# tensor(271)
# tensor(272)
# tensor(221)
# tensor(272)
# tensor(222)
# tensor(221)
# tensor(272)
# tensor(273)
# tensor(222)
# tensor(273)
# tensor(223)
# tensor(222)
# tensor(273)
# tensor(274)
# tensor(223)
# tensor(274)
# tensor(224)
# tensor(223)
# tensor(274)
# tensor(275)
# tensor(224)
# tensor(275)
# tensor(225)
# tensor(224)
# tensor(275)
# tensor(276)
# tensor(225)
# tensor(276)
# tensor(226)
# tensor(225)
# tensor(276)
# tensor(277)
# tensor(226)
# tensor(277)
# tensor(227)
# tensor(226)
# tensor(277)
# tensor(278)
# tensor(227)
# tensor(278)
# tensor(228)
# tensor(227)
# tensor(278)
# tensor(279)
# tensor(228)
# tensor(279)
# tensor(229)
# tensor(228)
# tensor(279)
# tensor(280)
# tensor(229)
# tensor(280)
# tensor(230)
# tensor(229)
# tensor(280)
# tensor(281)
# tensor(230)
# tensor(281)
# tensor(231)
# tensor(230)
# tensor(281)
# tensor(282)
# tensor(231)
# tensor(282)
# tensor(232)
# tensor(231)
# tensor(282)
# tensor(283)
# tensor(232)
# tensor(283)
# tensor(233)
# tensor(232)
# tensor(283)
# tensor(284)
# tensor(233)
# tensor(284)
# tensor(234)
# tensor(233)
# tensor(284)
# tensor(285)
# tensor(234)
# tensor(285)
# tensor(235)
# tensor(234)
# tensor(285)
# tensor(286)
# tensor(235)
# tensor(286)
# tensor(236)
# tensor(235)
# tensor(286)
# tensor(287)
# tensor(236)
# tensor(287)
# tensor(237)
# tensor(236)
# tensor(287)
# tensor(288)
# tensor(237)
# tensor(288)
# tensor(238)
# tensor(237)
# tensor(288)
# tensor(289)
# tensor(238)
# tensor(289)
# tensor(239)
# tensor(238)
# tensor(289)
# tensor(290)
# tensor(239)
# tensor(290)
# tensor(240)
# tensor(239)
# tensor(290)
# tensor(291)
# tensor(240)
# tensor(291)
# tensor(241)
# tensor(240)
# tensor(291)
# tensor(292)
# tensor(241)
# tensor(292)
# tensor(242)
# tensor(241)
# tensor(292)
# tensor(293)
# tensor(242)
# tensor(293)
# tensor(243)
# tensor(242)
# tensor(293)
# tensor(294)
# tensor(243)
# tensor(294)
# tensor(244)
# tensor(243)
# tensor(294)
# tensor(295)
# tensor(244)
# tensor(295)
# tensor(245)
# tensor(244)
# tensor(295)
# tensor(296)
# tensor(245)
# tensor(296)
# tensor(246)
# tensor(245)
# tensor(296)
# tensor(297)
# tensor(246)
# tensor(297)
# tensor(247)
# tensor(246)
# tensor(297)
# tensor(298)
# tensor(247)
# tensor(298)
# tensor(248)
# tensor(247)
# tensor(298)
# tensor(299)
# tensor(248)
# tensor(299)
# tensor(249)
# tensor(248)
# tensor(299)
# tensor(250)
# tensor(249)
# tensor(250)
# tensor(200)
# tensor(249)
# tensor(300)
# tensor(301)
# tensor(250)
# tensor(301)
# tensor(251)
# tensor(250)
# tensor(301)
# tensor(302)
# tensor(251)
# tensor(302)
# tensor(252)
# tensor(251)
# tensor(302)
# tensor(303)
# tensor(252)
# tensor(303)
# tensor(253)
# tensor(252)
# tensor(303)
# tensor(304)
# tensor(253)
# tensor(304)
# tensor(254)
# tensor(253)
# tensor(304)
# tensor(305)
# tensor(254)
# tensor(305)
# tensor(255)
# tensor(254)
# tensor(305)
# tensor(306)
# tensor(255)
# tensor(306)
# tensor(256)
# tensor(255)
# tensor(306)
# tensor(307)
# tensor(256)
# tensor(307)
# tensor(257)
# tensor(256)
# tensor(307)
# tensor(308)
# tensor(257)
# tensor(308)
# tensor(258)
# tensor(257)
# tensor(308)
# tensor(309)
# tensor(258)
# tensor(309)
# tensor(259)
# tensor(258)
# tensor(309)
# tensor(310)
# tensor(259)
# tensor(310)
# tensor(260)
# tensor(259)
# tensor(310)
# tensor(311)
# tensor(260)
# tensor(311)
# tensor(261)
# tensor(260)
# tensor(311)
# tensor(312)
# tensor(261)
# tensor(312)
# tensor(262)
# tensor(261)
# tensor(312)
# tensor(313)
# tensor(262)
# tensor(313)
# tensor(263)
# tensor(262)
# tensor(313)
# tensor(314)
# tensor(263)
# tensor(314)
# tensor(264)
# tensor(263)
# tensor(314)
# tensor(315)
# tensor(264)
# tensor(315)
# tensor(265)
# tensor(264)
# tensor(315)
# tensor(316)
# tensor(265)
# tensor(316)
# tensor(266)
# tensor(265)
# tensor(316)
# tensor(317)
# tensor(266)
# tensor(317)
# tensor(267)
# tensor(266)
# tensor(317)
# tensor(318)
# tensor(267)
# tensor(318)
# tensor(268)
# tensor(267)
# tensor(318)
# tensor(319)
# tensor(268)
# tensor(319)
# tensor(269)
# tensor(268)
# tensor(319)
# tensor(320)
# tensor(269)
# tensor(320)
# tensor(270)
# tensor(269)
# tensor(320)
# tensor(321)
# tensor(270)
# tensor(321)
# tensor(271)
# tensor(270)
# tensor(321)
# tensor(322)
# tensor(271)
# tensor(322)
# tensor(272)
# tensor(271)
# tensor(322)
# tensor(323)
# tensor(272)
# tensor(323)
# tensor(273)
# tensor(272)
# tensor(323)
# tensor(324)
# tensor(273)
# tensor(324)
# tensor(274)
# tensor(273)
# tensor(324)
# tensor(325)
# tensor(274)
# tensor(325)
# tensor(275)
# tensor(274)
# tensor(325)
# tensor(326)
# tensor(275)
# tensor(326)
# tensor(276)
# tensor(275)
# tensor(326)
# tensor(327)
# tensor(276)
# tensor(327)
# tensor(277)
# tensor(276)
# tensor(327)
# tensor(328)
# tensor(277)
# tensor(328)
# tensor(278)
# tensor(277)
# tensor(328)
# tensor(329)
# tensor(278)
# tensor(329)
# tensor(279)
# tensor(278)
# tensor(329)
# tensor(330)
# tensor(279)
# tensor(330)
# tensor(280)
# tensor(279)
# tensor(330)
# tensor(331)
# tensor(280)
# tensor(331)
# tensor(281)
# tensor(280)
# tensor(331)
# tensor(332)
# tensor(281)
# tensor(332)
# tensor(282)
# tensor(281)
# tensor(332)
# tensor(333)
# tensor(282)
# tensor(333)
# tensor(283)
# tensor(282)
# tensor(333)
# tensor(334)
# tensor(283)
# tensor(334)
# tensor(284)
# tensor(283)
# tensor(334)
# tensor(335)
# tensor(284)
# tensor(335)
# tensor(285)
# tensor(284)
# tensor(335)
# tensor(336)
# tensor(285)
# tensor(336)
# tensor(286)
# tensor(285)
# tensor(336)
# tensor(337)
# tensor(286)
# tensor(337)
# tensor(287)
# tensor(286)
# tensor(337)
# tensor(338)
# tensor(287)
# tensor(338)
# tensor(288)
# tensor(287)
# tensor(338)
# tensor(339)
# tensor(288)
# tensor(339)
# tensor(289)
# tensor(288)
# tensor(339)
# tensor(340)
# tensor(289)
# tensor(340)
# tensor(290)
# tensor(289)
# tensor(340)
# tensor(341)
# tensor(290)
# tensor(341)
# tensor(291)
# tensor(290)
# tensor(341)
# tensor(342)
# tensor(291)
# tensor(342)
# tensor(292)
# tensor(291)
# tensor(342)
# tensor(343)
# tensor(292)
# tensor(343)
# tensor(293)
# tensor(292)
# tensor(343)
# tensor(344)
# tensor(293)
# tensor(344)
# tensor(294)
# tensor(293)
# tensor(344)
# tensor(345)
# tensor(294)
# tensor(345)
# tensor(295)
# tensor(294)
# tensor(345)
# tensor(346)
# tensor(295)
# tensor(346)
# tensor(296)
# tensor(295)
# tensor(346)
# tensor(347)
# tensor(296)
# tensor(347)
# tensor(297)
# tensor(296)
# tensor(347)
# tensor(348)
# tensor(297)
# tensor(348)
# tensor(298)
# tensor(297)
# tensor(348)
# tensor(349)
# tensor(298)
# tensor(349)
# tensor(299)
# tensor(298)
# tensor(349)
# tensor(300)
# tensor(299)
# tensor(300)
# tensor(250)
# tensor(299)
# tensor(350)
# tensor(351)
# tensor(300)
# tensor(351)
# tensor(301)
# tensor(300)
# tensor(351)
# tensor(352)
# tensor(301)
# tensor(352)
# tensor(302)
# tensor(301)
# tensor(352)
# tensor(353)
# tensor(302)
# tensor(353)
# tensor(303)
# tensor(302)
# tensor(353)
# tensor(354)
# tensor(303)
# tensor(354)
# tensor(304)
# tensor(303)
# tensor(354)
# tensor(355)
# tensor(304)
# tensor(355)
# tensor(305)
# tensor(304)
# tensor(355)
# tensor(356)
# tensor(305)
# tensor(356)
# tensor(306)
# tensor(305)
# tensor(356)
# tensor(357)
# tensor(306)
# tensor(357)
# tensor(307)
# tensor(306)
# tensor(357)
# tensor(358)
# tensor(307)
# tensor(358)
# tensor(308)
# tensor(307)
# tensor(358)
# tensor(359)
# tensor(308)
# tensor(359)
# tensor(309)
# tensor(308)
# tensor(359)
# tensor(360)
# tensor(309)
# tensor(360)
# tensor(310)
# tensor(309)
# tensor(360)
# tensor(361)
# tensor(310)
# tensor(361)
# tensor(311)
# tensor(310)
# tensor(361)
# tensor(362)
# tensor(311)
# tensor(362)
# tensor(312)
# tensor(311)
# tensor(362)
# tensor(363)
# tensor(312)
# tensor(363)
# tensor(313)
# tensor(312)
# tensor(363)
# tensor(364)
# tensor(313)
# tensor(364)
# tensor(314)
# tensor(313)
# tensor(364)
# tensor(365)
# tensor(314)
# tensor(365)
# tensor(315)
# tensor(314)
# tensor(365)
# tensor(366)
# tensor(315)
# tensor(366)
# tensor(316)
# tensor(315)
# tensor(366)
# tensor(367)
# tensor(316)
# tensor(367)
# tensor(317)
# tensor(316)
# tensor(367)
# tensor(368)
# tensor(317)
# tensor(368)
# tensor(318)
# tensor(317)
# tensor(368)
# tensor(369)
# tensor(318)
# tensor(369)
# tensor(319)
# tensor(318)
# tensor(369)
# tensor(370)
# tensor(319)
# tensor(370)
# tensor(320)
# tensor(319)
# tensor(370)
# tensor(371)
# tensor(320)
# tensor(371)
# tensor(321)
# tensor(320)
# tensor(371)
# tensor(372)
# tensor(321)
# tensor(372)
# tensor(322)
# tensor(321)
# tensor(372)
# tensor(373)
# tensor(322)
# tensor(373)
# tensor(323)
# tensor(322)
# tensor(373)
# tensor(374)
# tensor(323)
# tensor(374)
# tensor(324)
# tensor(323)
# tensor(374)
# tensor(375)
# tensor(324)
# tensor(375)
# tensor(325)
# tensor(324)
# tensor(375)
# tensor(376)
# tensor(325)
# tensor(376)
# tensor(326)
# tensor(325)
# tensor(376)
# tensor(377)
# tensor(326)
# tensor(377)
# tensor(327)
# tensor(326)
# tensor(377)
# tensor(378)
# tensor(327)
# tensor(378)
# tensor(328)
# tensor(327)
# tensor(378)
# tensor(379)
# tensor(328)
# tensor(379)
# tensor(329)
# tensor(328)
# tensor(379)
# tensor(380)
# tensor(329)
# tensor(380)
# tensor(330)
# tensor(329)
# tensor(380)
# tensor(381)
# tensor(330)
# tensor(381)
# tensor(331)
# tensor(330)
# tensor(381)
# tensor(382)
# tensor(331)
# tensor(382)
# tensor(332)
# tensor(331)
# tensor(382)
# tensor(383)
# tensor(332)
# tensor(383)
# tensor(333)
# tensor(332)
# tensor(383)
# tensor(384)
# tensor(333)
# tensor(384)
# tensor(334)
# tensor(333)
# tensor(384)
# tensor(385)
# tensor(334)
# tensor(385)
# tensor(335)
# tensor(334)
# tensor(385)
# tensor(386)
# tensor(335)
# tensor(386)
# tensor(336)
# tensor(335)
# tensor(386)
# tensor(387)
# tensor(336)
# tensor(387)
# tensor(337)
# tensor(336)
# tensor(387)
# tensor(388)
# tensor(337)
# tensor(388)
# tensor(338)
# tensor(337)
# tensor(388)
# tensor(389)
# tensor(338)
# tensor(389)
# tensor(339)
# tensor(338)
# tensor(389)
# tensor(390)
# tensor(339)
# tensor(390)
# tensor(340)
# tensor(339)
# tensor(390)
# tensor(391)
# tensor(340)
# tensor(391)
# tensor(341)
# tensor(340)
# tensor(391)
# tensor(392)
# tensor(341)
# tensor(392)
# tensor(342)
# tensor(341)
# tensor(392)
# tensor(393)
# tensor(342)
# tensor(393)
# tensor(343)
# tensor(342)
# tensor(393)
# tensor(394)
# tensor(343)
# tensor(394)
# tensor(344)
# tensor(343)
# tensor(394)
# tensor(395)
# tensor(344)
# tensor(395)
# tensor(345)
# tensor(344)
# tensor(395)
# tensor(396)
# tensor(345)
# tensor(396)
# tensor(346)
# tensor(345)
# tensor(396)
# tensor(397)
# tensor(346)
# tensor(397)
# tensor(347)
# tensor(346)
# tensor(397)
# tensor(398)
# tensor(347)
# tensor(398)
# tensor(348)
# tensor(347)
# tensor(398)
# tensor(399)
# tensor(348)
# tensor(399)
# tensor(349)
# tensor(348)
# tensor(399)
# tensor(350)
# tensor(349)
# tensor(350)
# tensor(300)
# tensor(349)
# tensor(400)
# tensor(401)
# tensor(350)
# tensor(401)
# tensor(351)
# tensor(350)
# tensor(401)
# tensor(402)
# tensor(351)
# tensor(402)
# tensor(352)
# tensor(351)
# tensor(402)
# tensor(403)
# tensor(352)
# tensor(403)
# tensor(353)
# tensor(352)
# tensor(403)
# tensor(404)
# tensor(353)
# tensor(404)
# tensor(354)
# tensor(353)
# tensor(404)
# tensor(405)
# tensor(354)
# tensor(405)
# tensor(355)
# tensor(354)
# tensor(405)
# tensor(406)
# tensor(355)
# tensor(406)
# tensor(356)
# tensor(355)
# tensor(406)
# tensor(407)
# tensor(356)
# tensor(407)
# tensor(357)
# tensor(356)
# tensor(407)
# tensor(408)
# tensor(357)
# tensor(408)
# tensor(358)
# tensor(357)
# tensor(408)
# tensor(409)
# tensor(358)
# tensor(409)
# tensor(359)
# tensor(358)
# tensor(409)
# tensor(410)
# tensor(359)
# tensor(410)
# tensor(360)
# tensor(359)
# tensor(410)
# tensor(411)
# tensor(360)
# tensor(411)
# tensor(361)
# tensor(360)
# tensor(411)
# tensor(412)
# tensor(361)
# tensor(412)
# tensor(362)
# tensor(361)
# tensor(412)
# tensor(413)
# tensor(362)
# tensor(413)
# tensor(363)
# tensor(362)
# tensor(413)
# tensor(414)
# tensor(363)
# tensor(414)
# tensor(364)
# tensor(363)
# tensor(414)
# tensor(415)
# tensor(364)
# tensor(415)
# tensor(365)
# tensor(364)
# tensor(415)
# tensor(416)
# tensor(365)
# tensor(416)
# tensor(366)
# tensor(365)
# tensor(416)
# tensor(417)
# tensor(366)
# tensor(417)
# tensor(367)
# tensor(366)
# tensor(417)
# tensor(418)
# tensor(367)
# tensor(418)
# tensor(368)
# tensor(367)
# tensor(418)
# tensor(419)
# tensor(368)
# tensor(419)
# tensor(369)
# tensor(368)
# tensor(419)
# tensor(420)
# tensor(369)
# tensor(420)
# tensor(370)
# tensor(369)
# tensor(420)
# tensor(421)
# tensor(370)
# tensor(421)
# tensor(371)
# tensor(370)
# tensor(421)
# tensor(422)
# tensor(371)
# tensor(422)
# tensor(372)
# tensor(371)
# tensor(422)
# tensor(423)
# tensor(372)
# tensor(423)
# tensor(373)
# tensor(372)
# tensor(423)
# tensor(424)
# tensor(373)
# tensor(424)
# tensor(374)
# tensor(373)
# tensor(424)
# tensor(425)
# tensor(374)
# tensor(425)
# tensor(375)
# tensor(374)
# tensor(425)
# tensor(426)
# tensor(375)
# tensor(426)
# tensor(376)
# tensor(375)
# tensor(426)
# tensor(427)
# tensor(376)
# tensor(427)
# tensor(377)
# tensor(376)
# tensor(427)
# tensor(428)
# tensor(377)
# tensor(428)
# tensor(378)
# tensor(377)
# tensor(428)
# tensor(429)
# tensor(378)
# tensor(429)
# tensor(379)
# tensor(378)
# tensor(429)
# tensor(430)
# tensor(379)
# tensor(430)
# tensor(380)
# tensor(379)
# tensor(430)
# tensor(431)
# tensor(380)
# tensor(431)
# tensor(381)
# tensor(380)
# tensor(431)
# tensor(432)
# tensor(381)
# tensor(432)
# tensor(382)
# tensor(381)
# tensor(432)
# tensor(433)
# tensor(382)
# tensor(433)
# tensor(383)
# tensor(382)
# tensor(433)
# tensor(434)
# tensor(383)
# tensor(434)
# tensor(384)
# tensor(383)
# tensor(434)
# tensor(435)
# tensor(384)
# tensor(435)
# tensor(385)
# tensor(384)
# tensor(435)
# tensor(436)
# tensor(385)
# tensor(436)
# tensor(386)
# tensor(385)
# tensor(436)
# tensor(437)
# tensor(386)
# tensor(437)
# tensor(387)
# tensor(386)
# tensor(437)
# tensor(438)
# tensor(387)
# tensor(438)
# tensor(388)
# tensor(387)
# tensor(438)
# tensor(439)
# tensor(388)
# tensor(439)
# tensor(389)
# tensor(388)
# tensor(439)
# tensor(440)
# tensor(389)
# tensor(440)
# tensor(390)
# tensor(389)
# tensor(440)
# tensor(441)
# tensor(390)
# tensor(441)
# tensor(391)
# tensor(390)
# tensor(441)
# tensor(442)
# tensor(391)
# tensor(442)
# tensor(392)
# tensor(391)
# tensor(442)
# tensor(443)
# tensor(392)
# tensor(443)
# tensor(393)
# tensor(392)
# tensor(443)
# tensor(444)
# tensor(393)
# tensor(444)
# tensor(394)
# tensor(393)
# tensor(444)
# tensor(445)
# tensor(394)
# tensor(445)
# tensor(395)
# tensor(394)
# tensor(445)
# tensor(446)
# tensor(395)
# tensor(446)
# tensor(396)
# tensor(395)
# tensor(446)
# tensor(447)
# tensor(396)
# tensor(447)
# tensor(397)
# tensor(396)
# tensor(447)
# tensor(448)
# tensor(397)
# tensor(448)
# tensor(398)
# tensor(397)
# tensor(448)
# tensor(449)
# tensor(398)
# tensor(449)
# tensor(399)
# tensor(398)
# tensor(449)
# tensor(400)
# tensor(399)
# tensor(400)
# tensor(350)
# tensor(399)
# tensor(450)
# tensor(451)
# tensor(400)
# tensor(451)
# tensor(401)
# tensor(400)
# tensor(451)
# tensor(452)
# tensor(401)
# tensor(452)
# tensor(402)
# tensor(401)
# tensor(452)
# tensor(453)
# tensor(402)
# tensor(453)
# tensor(403)
# tensor(402)
# tensor(453)
# tensor(454)
# tensor(403)
# tensor(454)
# tensor(404)
# tensor(403)
# tensor(454)
# tensor(455)
# tensor(404)
# tensor(455)
# tensor(405)
# tensor(404)
# tensor(455)
# tensor(456)
# tensor(405)
# tensor(456)
# tensor(406)
# tensor(405)
# tensor(456)
# tensor(457)
# tensor(406)
# tensor(457)
# tensor(407)
# tensor(406)
# tensor(457)
# tensor(458)
# tensor(407)
# tensor(458)
# tensor(408)
# tensor(407)
# tensor(458)
# tensor(459)
# tensor(408)
# tensor(459)
# tensor(409)
# tensor(408)
# tensor(459)
# tensor(460)
# tensor(409)
# tensor(460)
# tensor(410)
# tensor(409)
# tensor(460)
# tensor(461)
# tensor(410)
# tensor(461)
# tensor(411)
# tensor(410)
# tensor(461)
# tensor(462)
# tensor(411)
# tensor(462)
# tensor(412)
# tensor(411)
# tensor(462)
# tensor(463)
# tensor(412)
# tensor(463)
# tensor(413)
# tensor(412)
# tensor(463)
# tensor(464)
# tensor(413)
# tensor(464)
# tensor(414)
# tensor(413)
# tensor(464)
# tensor(465)
# tensor(414)
# tensor(465)
# tensor(415)
# tensor(414)
# tensor(465)
# tensor(466)
# tensor(415)
# tensor(466)
# tensor(416)
# tensor(415)
# tensor(466)
# tensor(467)
# tensor(416)
# tensor(467)
# tensor(417)
# tensor(416)
# tensor(467)
# tensor(468)
# tensor(417)
# tensor(468)
# tensor(418)
# tensor(417)
# tensor(468)
# tensor(469)
# tensor(418)
# tensor(469)
# tensor(419)
# tensor(418)
# tensor(469)
# tensor(470)
# tensor(419)
# tensor(470)
# tensor(420)
# tensor(419)
# tensor(470)
# tensor(471)
# tensor(420)
# tensor(471)
# tensor(421)
# tensor(420)
# tensor(471)
# tensor(472)
# tensor(421)
# tensor(472)
# tensor(422)
# tensor(421)
# tensor(472)
# tensor(473)
# tensor(422)
# tensor(473)
# tensor(423)
# tensor(422)
# tensor(473)
# tensor(474)
# tensor(423)
# tensor(474)
# tensor(424)
# tensor(423)
# tensor(474)
# tensor(475)
# tensor(424)
# tensor(475)
# tensor(425)
# tensor(424)
# tensor(475)
# tensor(476)
# tensor(425)
# tensor(476)
# tensor(426)
# tensor(425)
# tensor(476)
# tensor(477)
# tensor(426)
# tensor(477)
# tensor(427)
# tensor(426)
# tensor(477)
# tensor(478)
# tensor(427)
# tensor(478)
# tensor(428)
# tensor(427)
# tensor(478)
# tensor(479)
# tensor(428)
# tensor(479)
# tensor(429)
# tensor(428)
# tensor(479)
# tensor(480)
# tensor(429)
# tensor(480)
# tensor(430)
# tensor(429)
# tensor(480)
# tensor(481)
# tensor(430)
# tensor(481)
# tensor(431)
# tensor(430)
# tensor(481)
# tensor(482)
# tensor(431)
# tensor(482)
# tensor(432)
# tensor(431)
# tensor(482)
# tensor(483)
# tensor(432)
# tensor(483)
# tensor(433)
# tensor(432)
# tensor(483)
# tensor(484)
# tensor(433)
# tensor(484)
# tensor(434)
# tensor(433)
# tensor(484)
# tensor(485)
# tensor(434)
# tensor(485)
# tensor(435)
# tensor(434)
# tensor(485)
# tensor(486)
# tensor(435)
# tensor(486)
# tensor(436)
# tensor(435)
# tensor(486)
# tensor(487)
# tensor(436)
# tensor(487)
# tensor(437)
# tensor(436)
# tensor(487)
# tensor(488)
# tensor(437)
# tensor(488)
# tensor(438)
# tensor(437)
# tensor(488)
# tensor(489)
# tensor(438)
# tensor(489)
# tensor(439)
# tensor(438)
# tensor(489)
# tensor(490)
# tensor(439)
# tensor(490)
# tensor(440)
# tensor(439)
# tensor(490)
# tensor(491)
# tensor(440)
# tensor(491)
# tensor(441)
# tensor(440)
# tensor(491)
# tensor(492)
# tensor(441)
# tensor(492)
# tensor(442)
# tensor(441)
# tensor(492)
# tensor(493)
# tensor(442)
# tensor(493)
# tensor(443)
# tensor(442)
# tensor(493)
# tensor(494)
# tensor(443)
# tensor(494)
# tensor(444)
# tensor(443)
# tensor(494)
# tensor(495)
# tensor(444)
# tensor(495)
# tensor(445)
# tensor(444)
# tensor(495)
# tensor(496)
# tensor(445)
# tensor(496)
# tensor(446)
# tensor(445)
# tensor(496)
# tensor(497)
# tensor(446)
# tensor(497)
# tensor(447)
# tensor(446)
# tensor(497)
# tensor(498)
# tensor(447)
# tensor(498)
# tensor(448)
# tensor(447)
# tensor(498)
# tensor(499)
# tensor(448)
# tensor(499)
# tensor(449)
# tensor(448)
# tensor(499)
# tensor(450)
# tensor(449)
# tensor(450)
# tensor(400)
# tensor(449)
# tensor(500)
# tensor(501)
# tensor(450)
# tensor(501)
# tensor(451)
# tensor(450)
# tensor(501)
# tensor(502)
# tensor(451)
# tensor(502)
# tensor(452)
# tensor(451)
# tensor(502)
# tensor(503)
# tensor(452)
# tensor(503)
# tensor(453)
# tensor(452)
# tensor(503)
# tensor(504)
# tensor(453)
# tensor(504)
# tensor(454)
# tensor(453)
# tensor(504)
# tensor(505)
# tensor(454)
# tensor(505)
# tensor(455)
# tensor(454)
# tensor(505)
# tensor(506)
# tensor(455)
# tensor(506)
# tensor(456)
# tensor(455)
# tensor(506)
# tensor(507)
# tensor(456)
# tensor(507)
# tensor(457)
# tensor(456)
# tensor(507)
# tensor(508)
# tensor(457)
# tensor(508)
# tensor(458)
# tensor(457)
# tensor(508)
# tensor(509)
# tensor(458)
# tensor(509)
# tensor(459)
# tensor(458)
# tensor(509)
# tensor(510)
# tensor(459)
# tensor(510)
# tensor(460)
# tensor(459)
# tensor(510)
# tensor(511)
# tensor(460)
# tensor(511)
# tensor(461)
# tensor(460)
# tensor(511)
# tensor(512)
# tensor(461)
# tensor(512)
# tensor(462)
# tensor(461)
# tensor(512)
# tensor(513)
# tensor(462)
# tensor(513)
# tensor(463)
# tensor(462)
# tensor(513)
# tensor(514)
# tensor(463)
# tensor(514)
# tensor(464)
# tensor(463)
# tensor(514)
# tensor(515)
# tensor(464)
# tensor(515)
# tensor(465)
# tensor(464)
# tensor(515)
# tensor(516)
# tensor(465)
# tensor(516)
# tensor(466)
# tensor(465)
# tensor(516)
# tensor(517)
# tensor(466)
# tensor(517)
# tensor(467)
# tensor(466)
# tensor(517)
# tensor(518)
# tensor(467)
# tensor(518)
# tensor(468)
# tensor(467)
# tensor(518)
# tensor(519)
# tensor(468)
# tensor(519)
# tensor(469)
# tensor(468)
# tensor(519)
# tensor(520)
# tensor(469)
# tensor(520)
# tensor(470)
# tensor(469)
# tensor(520)
# tensor(521)
# tensor(470)
# tensor(521)
# tensor(471)
# tensor(470)
# tensor(521)
# tensor(522)
# tensor(471)
# tensor(522)
# tensor(472)
# tensor(471)
# tensor(522)
# tensor(523)
# tensor(472)
# tensor(523)
# tensor(473)
# tensor(472)
# tensor(523)
# tensor(524)
# tensor(473)
# tensor(524)
# tensor(474)
# tensor(473)
# tensor(524)
# tensor(525)
# tensor(474)
# tensor(525)
# tensor(475)
# tensor(474)
# tensor(525)
# tensor(526)
# tensor(475)
# tensor(526)
# tensor(476)
# tensor(475)
# tensor(526)
# tensor(527)
# tensor(476)
# tensor(527)
# tensor(477)
# tensor(476)
# tensor(527)
# tensor(528)
# tensor(477)
# tensor(528)
# tensor(478)
# tensor(477)
# tensor(528)
# tensor(529)
# tensor(478)
# tensor(529)
# tensor(479)
# tensor(478)
# tensor(529)
# tensor(530)
# tensor(479)
# tensor(530)
# tensor(480)
# tensor(479)
# tensor(530)
# tensor(531)
# tensor(480)
# tensor(531)
# tensor(481)
# tensor(480)
# tensor(531)
# tensor(532)
# tensor(481)
# tensor(532)
# tensor(482)
# tensor(481)
# tensor(532)
# tensor(533)
# tensor(482)
# tensor(533)
# tensor(483)
# tensor(482)
# tensor(533)
# tensor(534)
# tensor(483)
# tensor(534)
# tensor(484)
# tensor(483)
# tensor(534)
# tensor(535)
# tensor(484)
# tensor(535)
# tensor(485)
# tensor(484)
# tensor(535)
# tensor(536)
# tensor(485)
# tensor(536)
# tensor(486)
# tensor(485)
# tensor(536)
# tensor(537)
# tensor(486)
# tensor(537)
# tensor(487)
# tensor(486)
# tensor(537)
# tensor(538)
# tensor(487)
# tensor(538)
# tensor(488)
# tensor(487)
# tensor(538)
# tensor(539)
# tensor(488)
# tensor(539)
# tensor(489)
# tensor(488)
# tensor(539)
# tensor(540)
# tensor(489)
# tensor(540)
# tensor(490)
# tensor(489)
# tensor(540)
# tensor(541)
# tensor(490)
# tensor(541)
# tensor(491)
# tensor(490)
# tensor(541)
# tensor(542)
# tensor(491)
# tensor(542)
# tensor(492)
# tensor(491)
# tensor(542)
# tensor(543)
# tensor(492)
# tensor(543)
# tensor(493)
# tensor(492)
# tensor(543)
# tensor(544)
# tensor(493)
# tensor(544)
# tensor(494)
# tensor(493)
# tensor(544)
# tensor(545)
# tensor(494)
# tensor(545)
# tensor(495)
# tensor(494)
# tensor(545)
# tensor(546)
# tensor(495)
# tensor(546)
# tensor(496)
# tensor(495)
# tensor(546)
# tensor(547)
# tensor(496)
# tensor(547)
# tensor(497)
# tensor(496)
# tensor(547)
# tensor(548)
# tensor(497)
# tensor(548)
# tensor(498)
# tensor(497)
# tensor(548)
# tensor(549)
# tensor(498)
# tensor(549)
# tensor(499)
# tensor(498)
# tensor(549)
# tensor(500)
# tensor(499)
# tensor(500)
# tensor(450)
# tensor(499)
# tensor(550)
# tensor(551)
# tensor(500)
# tensor(551)
# tensor(501)
# tensor(500)
# tensor(551)
# tensor(552)
# tensor(501)
# tensor(552)
# tensor(502)
# tensor(501)
# tensor(552)
# tensor(553)
# tensor(502)
# tensor(553)
# tensor(503)
# tensor(502)
# tensor(553)
# tensor(554)
# tensor(503)
# tensor(554)
# tensor(504)
# tensor(503)
# tensor(554)
# tensor(555)
# tensor(504)
# tensor(555)
# tensor(505)
# tensor(504)
# tensor(555)
# tensor(556)
# tensor(505)
# tensor(556)
# tensor(506)
# tensor(505)
# tensor(556)
# tensor(557)
# tensor(506)
# tensor(557)
# tensor(507)
# tensor(506)
# tensor(557)
# tensor(558)
# tensor(507)
# tensor(558)
# tensor(508)
# tensor(507)
# tensor(558)
# tensor(559)
# tensor(508)
# tensor(559)
# tensor(509)
# tensor(508)
# tensor(559)
# tensor(560)
# tensor(509)
# tensor(560)
# tensor(510)
# tensor(509)
# tensor(560)
# tensor(561)
# tensor(510)
# tensor(561)
# tensor(511)
# tensor(510)
# tensor(561)
# tensor(562)
# tensor(511)
# tensor(562)
# tensor(512)
# tensor(511)
# tensor(562)
# tensor(563)
# tensor(512)
# tensor(563)
# tensor(513)
# tensor(512)
# tensor(563)
# tensor(564)
# tensor(513)
# tensor(564)
# tensor(514)
# tensor(513)
# tensor(564)
# tensor(565)
# tensor(514)
# tensor(565)
# tensor(515)
# tensor(514)
# tensor(565)
# tensor(566)
# tensor(515)
# tensor(566)
# tensor(516)
# tensor(515)
# tensor(566)
# tensor(567)
# tensor(516)
# tensor(567)
# tensor(517)
# tensor(516)
# tensor(567)
# tensor(568)
# tensor(517)
# tensor(568)
# tensor(518)
# tensor(517)
# tensor(568)
# tensor(569)
# tensor(518)
# tensor(569)
# tensor(519)
# tensor(518)
# tensor(569)
# tensor(570)
# tensor(519)
# tensor(570)
# tensor(520)
# tensor(519)
# tensor(570)
# tensor(571)
# tensor(520)
# tensor(571)
# tensor(521)
# tensor(520)
# tensor(571)
# tensor(572)
# tensor(521)
# tensor(572)
# tensor(522)
# tensor(521)
# tensor(572)
# tensor(573)
# tensor(522)
# tensor(573)
# tensor(523)
# tensor(522)
# tensor(573)
# tensor(574)
# tensor(523)
# tensor(574)
# tensor(524)
# tensor(523)
# tensor(574)
# tensor(575)
# tensor(524)
# tensor(575)
# tensor(525)
# tensor(524)
# tensor(575)
# tensor(576)
# tensor(525)
# tensor(576)
# tensor(526)
# tensor(525)
# tensor(576)
# tensor(577)
# tensor(526)
# tensor(577)
# tensor(527)
# tensor(526)
# tensor(577)
# tensor(578)
# tensor(527)
# tensor(578)
# tensor(528)
# tensor(527)
# tensor(578)
# tensor(579)
# tensor(528)
# tensor(579)
# tensor(529)
# tensor(528)
# tensor(579)
# tensor(580)
# tensor(529)
# tensor(580)
# tensor(530)
# tensor(529)
# tensor(580)
# tensor(581)
# tensor(530)
# tensor(581)
# tensor(531)
# tensor(530)
# tensor(581)
# tensor(582)
# tensor(531)
# tensor(582)
# tensor(532)
# tensor(531)
# tensor(582)
# tensor(583)
# tensor(532)
# tensor(583)
# tensor(533)
# tensor(532)
# tensor(583)
# tensor(584)
# tensor(533)
# tensor(584)
# tensor(534)
# tensor(533)
# tensor(584)
# tensor(585)
# tensor(534)
# tensor(585)
# tensor(535)
# tensor(534)
# tensor(585)
# tensor(586)
# tensor(535)
# tensor(586)
# tensor(536)
# tensor(535)
# tensor(586)
# tensor(587)
# tensor(536)
# tensor(587)
# tensor(537)
# tensor(536)
# tensor(587)
# tensor(588)
# tensor(537)
# tensor(588)
# tensor(538)
# tensor(537)
# tensor(588)
# tensor(589)
# tensor(538)
# tensor(589)
# tensor(539)
# tensor(538)
# tensor(589)
# tensor(590)
# tensor(539)
# tensor(590)
# tensor(540)
# tensor(539)
# tensor(590)
# tensor(591)
# tensor(540)
# tensor(591)
# tensor(541)
# tensor(540)
# tensor(591)
# tensor(592)
# tensor(541)
# tensor(592)
# tensor(542)
# tensor(541)
# tensor(592)
# tensor(593)
# tensor(542)
# tensor(593)
# tensor(543)
# tensor(542)
# tensor(593)
# tensor(594)
# tensor(543)
# tensor(594)
# tensor(544)
# tensor(543)
# tensor(594)
# tensor(595)
# tensor(544)
# tensor(595)
# tensor(545)
# tensor(544)
# tensor(595)
# tensor(596)
# tensor(545)
# tensor(596)
# tensor(546)
# tensor(545)
# tensor(596)
# tensor(597)
# tensor(546)
# tensor(597)
# tensor(547)
# tensor(546)
# tensor(597)
# tensor(598)
# tensor(547)
# tensor(598)
# tensor(548)
# tensor(547)
# tensor(598)
# tensor(599)
# tensor(548)
# tensor(599)
# tensor(549)
# tensor(548)
# tensor(599)
# tensor(550)
# tensor(549)
# tensor(550)
# tensor(500)
# tensor(549)
# tensor(600)
# tensor(601)
# tensor(550)
# tensor(601)
# tensor(551)
# tensor(550)
# tensor(601)
# tensor(602)
# tensor(551)
# tensor(602)
# tensor(552)
# tensor(551)
# tensor(602)
# tensor(603)
# tensor(552)
# tensor(603)
# tensor(553)
# tensor(552)
# tensor(603)
# tensor(604)
# tensor(553)
# tensor(604)
# tensor(554)
# tensor(553)
# tensor(604)
# tensor(605)
# tensor(554)
# tensor(605)
# tensor(555)
# tensor(554)
# tensor(605)
# tensor(606)
# tensor(555)
# tensor(606)
# tensor(556)
# tensor(555)
# tensor(606)
# tensor(607)
# tensor(556)
# tensor(607)
# tensor(557)
# tensor(556)
# tensor(607)
# tensor(608)
# tensor(557)
# tensor(608)
# tensor(558)
# tensor(557)
# tensor(608)
# tensor(609)
# tensor(558)
# tensor(609)
# tensor(559)
# tensor(558)
# tensor(609)
# tensor(610)
# tensor(559)
# tensor(610)
# tensor(560)
# tensor(559)
# tensor(610)
# tensor(611)
# tensor(560)
# tensor(611)
# tensor(561)
# tensor(560)
# tensor(611)
# tensor(612)
# tensor(561)
# tensor(612)
# tensor(562)
# tensor(561)
# tensor(612)
# tensor(613)
# tensor(562)
# tensor(613)
# tensor(563)
# tensor(562)
# tensor(613)
# tensor(614)
# tensor(563)
# tensor(614)
# tensor(564)
# tensor(563)
# tensor(614)
# tensor(615)
# tensor(564)
# tensor(615)
# tensor(565)
# tensor(564)
# tensor(615)
# tensor(616)
# tensor(565)
# tensor(616)
# tensor(566)
# tensor(565)
# tensor(616)
# tensor(617)
# tensor(566)
# tensor(617)
# tensor(567)
# tensor(566)
# tensor(617)
# tensor(618)
# tensor(567)
# tensor(618)
# tensor(568)
# tensor(567)
# tensor(618)
# tensor(619)
# tensor(568)
# tensor(619)
# tensor(569)
# tensor(568)
# tensor(619)
# tensor(620)
# tensor(569)
# tensor(620)
# tensor(570)
# tensor(569)
# tensor(620)
# tensor(621)
# tensor(570)
# tensor(621)
# tensor(571)
# tensor(570)
# tensor(621)
# tensor(622)
# tensor(571)
# tensor(622)
# tensor(572)
# tensor(571)
# tensor(622)
# tensor(623)
# tensor(572)
# tensor(623)
# tensor(573)
# tensor(572)
# tensor(623)
# tensor(624)
# tensor(573)
# tensor(624)
# tensor(574)
# tensor(573)
# tensor(624)
# tensor(625)
# tensor(574)
# tensor(625)
# tensor(575)
# tensor(574)
# tensor(625)
# tensor(626)
# tensor(575)
# tensor(626)
# tensor(576)
# tensor(575)
# tensor(626)
# tensor(627)
# tensor(576)
# tensor(627)
# tensor(577)
# tensor(576)
# tensor(627)
# tensor(628)
# tensor(577)
# tensor(628)
# tensor(578)
# tensor(577)
# tensor(628)
# tensor(629)
# tensor(578)
# tensor(629)
# tensor(579)
# tensor(578)
# tensor(629)
# tensor(630)
# tensor(579)
# tensor(630)
# tensor(580)
# tensor(579)
# tensor(630)
# tensor(631)
# tensor(580)
# tensor(631)
# tensor(581)
# tensor(580)
# tensor(631)
# tensor(632)
# tensor(581)
# tensor(632)
# tensor(582)
# tensor(581)
# tensor(632)
# tensor(633)
# tensor(582)
# tensor(633)
# tensor(583)
# tensor(582)
# tensor(633)
# tensor(634)
# tensor(583)
# tensor(634)
# tensor(584)
# tensor(583)
# tensor(634)
# tensor(635)
# tensor(584)
# tensor(635)
# tensor(585)
# tensor(584)
# tensor(635)
# tensor(636)
# tensor(585)
# tensor(636)
# tensor(586)
# tensor(585)
# tensor(636)
# tensor(637)
# tensor(586)
# tensor(637)
# tensor(587)
# tensor(586)
# tensor(637)
# tensor(638)
# tensor(587)
# tensor(638)
# tensor(588)
# tensor(587)
# tensor(638)
# tensor(639)
# tensor(588)
# tensor(639)
# tensor(589)
# tensor(588)
# tensor(639)
# tensor(640)
# tensor(589)
# tensor(640)
# tensor(590)
# tensor(589)
# tensor(640)
# tensor(641)
# tensor(590)
# tensor(641)
# tensor(591)
# tensor(590)
# tensor(641)
# tensor(642)
# tensor(591)
# tensor(642)
# tensor(592)
# tensor(591)
# tensor(642)
# tensor(643)
# tensor(592)
# tensor(643)
# tensor(593)
# tensor(592)
# tensor(643)
# tensor(644)
# tensor(593)
# tensor(644)
# tensor(594)
# tensor(593)
# tensor(644)
# tensor(645)
# tensor(594)
# tensor(645)
# tensor(595)
# tensor(594)
# tensor(645)
# tensor(646)
# tensor(595)
# tensor(646)
# tensor(596)
# tensor(595)
# tensor(646)
# tensor(647)
# tensor(596)
# tensor(647)
# tensor(597)
# tensor(596)
# tensor(647)
# tensor(648)
# tensor(597)
# tensor(648)
# tensor(598)
# tensor(597)
# tensor(648)
# tensor(649)
# tensor(598)
# tensor(649)
# tensor(599)
# tensor(598)
# tensor(649)
# tensor(600)
# tensor(599)
# tensor(600)
# tensor(550)
# tensor(599)
# tensor(650)
# tensor(651)
# tensor(600)
# tensor(651)
# tensor(601)
# tensor(600)
# tensor(651)
# tensor(652)
# tensor(601)
# tensor(652)
# tensor(602)
# tensor(601)
# tensor(652)
# tensor(653)
# tensor(602)
# tensor(653)
# tensor(603)
# tensor(602)
# tensor(653)
# tensor(654)
# tensor(603)
# tensor(654)
# tensor(604)
# tensor(603)
# tensor(654)
# tensor(655)
# tensor(604)
# tensor(655)
# tensor(605)
# tensor(604)
# tensor(655)
# tensor(656)
# tensor(605)
# tensor(656)
# tensor(606)
# tensor(605)
# tensor(656)
# tensor(657)
# tensor(606)
# tensor(657)
# tensor(607)
# tensor(606)
# tensor(657)
# tensor(658)
# tensor(607)
# tensor(658)
# tensor(608)
# tensor(607)
# tensor(658)
# tensor(659)
# tensor(608)
# tensor(659)
# tensor(609)
# tensor(608)
# tensor(659)
# tensor(660)
# tensor(609)
# tensor(660)
# tensor(610)
# tensor(609)
# tensor(660)
# tensor(661)
# tensor(610)
# tensor(661)
# tensor(611)
# tensor(610)
# tensor(661)
# tensor(662)
# tensor(611)
# tensor(662)
# tensor(612)
# tensor(611)
# tensor(662)
# tensor(663)
# tensor(612)
# tensor(663)
# tensor(613)
# tensor(612)
# tensor(663)
# tensor(664)
# tensor(613)
# tensor(664)
# tensor(614)
# tensor(613)
# tensor(664)
# tensor(665)
# tensor(614)
# tensor(665)
# tensor(615)
# tensor(614)
# tensor(665)
# tensor(666)
# tensor(615)
# tensor(666)
# tensor(616)
# tensor(615)
# tensor(666)
# tensor(667)
# tensor(616)
# tensor(667)
# tensor(617)
# tensor(616)
# tensor(667)
# tensor(668)
# tensor(617)
# tensor(668)
# tensor(618)
# tensor(617)
# tensor(668)
# tensor(669)
# tensor(618)
# tensor(669)
# tensor(619)
# tensor(618)
# tensor(669)
# tensor(670)
# tensor(619)
# tensor(670)
# tensor(620)
# tensor(619)
# tensor(670)
# tensor(671)
# tensor(620)
# tensor(671)
# tensor(621)
# tensor(620)
# tensor(671)
# tensor(672)
# tensor(621)
# tensor(672)
# tensor(622)
# tensor(621)
# tensor(672)
# tensor(673)
# tensor(622)
# tensor(673)
# tensor(623)
# tensor(622)
# tensor(673)
# tensor(674)
# tensor(623)
# tensor(674)
# tensor(624)
# tensor(623)
# tensor(674)
# tensor(675)
# tensor(624)
# tensor(675)
# tensor(625)
# tensor(624)
# tensor(675)
# tensor(676)
# tensor(625)
# tensor(676)
# tensor(626)
# tensor(625)
# tensor(676)
# tensor(677)
# tensor(626)
# tensor(677)
# tensor(627)
# tensor(626)
# tensor(677)
# tensor(678)
# tensor(627)
# tensor(678)
# tensor(628)
# tensor(627)
# tensor(678)
# tensor(679)
# tensor(628)
# tensor(679)
# tensor(629)
# tensor(628)
# tensor(679)
# tensor(680)
# tensor(629)
# tensor(680)
# tensor(630)
# tensor(629)
# tensor(680)
# tensor(681)
# tensor(630)
# tensor(681)
# tensor(631)
# tensor(630)
# tensor(681)
# tensor(682)
# tensor(631)
# tensor(682)
# tensor(632)
# tensor(631)
# tensor(682)
# tensor(683)
# tensor(632)
# tensor(683)
# tensor(633)
# tensor(632)
# tensor(683)
# tensor(684)
# tensor(633)
# tensor(684)
# tensor(634)
# tensor(633)
# tensor(684)
# tensor(685)
# tensor(634)
# tensor(685)
# tensor(635)
# tensor(634)
# tensor(685)
# tensor(686)
# tensor(635)
# tensor(686)
# tensor(636)
# tensor(635)
# tensor(686)
# tensor(687)
# tensor(636)
# tensor(687)
# tensor(637)
# tensor(636)
# tensor(687)
# tensor(688)
# tensor(637)
# tensor(688)
# tensor(638)
# tensor(637)
# tensor(688)
# tensor(689)
# tensor(638)
# tensor(689)
# tensor(639)
# tensor(638)
# tensor(689)
# tensor(690)
# tensor(639)
# tensor(690)
# tensor(640)
# tensor(639)
# tensor(690)
# tensor(691)
# tensor(640)
# tensor(691)
# tensor(641)
# tensor(640)
# tensor(691)
# tensor(692)
# tensor(641)
# tensor(692)
# tensor(642)
# tensor(641)
# tensor(692)
# tensor(693)
# tensor(642)
# tensor(693)
# tensor(643)
# tensor(642)
# tensor(693)
# tensor(694)
# tensor(643)
# tensor(694)
# tensor(644)
# tensor(643)
# tensor(694)
# tensor(695)
# tensor(644)
# tensor(695)
# tensor(645)
# tensor(644)
# tensor(695)
# tensor(696)
# tensor(645)
# tensor(696)
# tensor(646)
# tensor(645)
# tensor(696)
# tensor(697)
# tensor(646)
# tensor(697)
# tensor(647)
# tensor(646)
# tensor(697)
# tensor(698)
# tensor(647)
# tensor(698)
# tensor(648)
# tensor(647)
# tensor(698)
# tensor(699)
# tensor(648)
# tensor(699)
# tensor(649)
# tensor(648)
# tensor(699)
# tensor(650)
# tensor(649)
# tensor(650)
# tensor(600)
# tensor(649)
# tensor(700)
# tensor(701)
# tensor(650)
# tensor(701)
# tensor(651)
# tensor(650)
# tensor(701)
# tensor(702)
# tensor(651)
# tensor(702)
# ...
# tensor(1070)
# tensor(1019)
# tensor(1070)
# tensor(1020)
# tensor(1019)
# tensor(1070)
# tensor(1071)
# tensor(1020)
# tensor(1071)
# tensor(1021)
# tensor(1020)
# tensor(1071)
# tensor(1072)
# tensor(1021)
# tensor(1072)
# tensor(1022)
# tensor(1021)
# tensor(1072)
# tensor(1073)
# tensor(1022)
# tensor(1073)
# tensor(1023)
# tensor(1022)
# tensor(1073)
# tensor(1074)
# tensor(1023)
# tensor(1074)
# tensor(1024)
# tensor(1023)
# tensor(1074)
# tensor(1075)
# tensor(1024)
# tensor(1075)
# tensor(1025)
# tensor(1024)
# tensor(1075)
# tensor(1076)
# tensor(1025)
# tensor(1076)
# tensor(1026)
# tensor(1025)
# tensor(1076)
# tensor(1077)
# tensor(1026)
# tensor(1077)
# tensor(1027)
# tensor(1026)
# tensor(1077)
# tensor(1078)
# tensor(1027)
# tensor(1078)
# tensor(1028)
# tensor(1027)
# tensor(1078)
# tensor(1079)
# tensor(1028)
# tensor(1079)
# tensor(1029)
# tensor(1028)
# tensor(1079)
# tensor(1080)
# tensor(1029)
# tensor(1080)
# tensor(1030)
# tensor(1029)
# tensor(1080)
# tensor(1081)
# tensor(1030)
# tensor(1081)
# tensor(1031)
# tensor(1030)
# tensor(1081)
# tensor(1082)
# tensor(1031)
# tensor(1082)
# tensor(1032)
# tensor(1031)
# tensor(1082)
# tensor(1083)
# tensor(1032)
# tensor(1083)
# tensor(1033)
# tensor(1032)
# tensor(1083)
# tensor(1084)
# tensor(1033)
# tensor(1084)
# tensor(1034)
# tensor(1033)
# tensor(1084)
# tensor(1085)
# tensor(1034)
# tensor(1085)
# tensor(1035)
# tensor(1034)
# tensor(1085)
# tensor(1086)
# tensor(1035)
# tensor(1086)
# tensor(1036)
# tensor(1035)
# tensor(1086)
# tensor(1087)
# tensor(1036)
# tensor(1087)
# tensor(1037)
# tensor(1036)
# tensor(1087)
# tensor(1088)
# tensor(1037)
# tensor(1088)
# tensor(1038)
# tensor(1037)
# tensor(1088)
# tensor(1089)
# tensor(1038)
# tensor(1089)
# tensor(1039)
# tensor(1038)
# tensor(1089)
# tensor(1090)
# tensor(1039)
# tensor(1090)
# tensor(1040)
# tensor(1039)
# tensor(1090)
# tensor(1091)
# tensor(1040)
# tensor(1091)
# tensor(1041)
# tensor(1040)
# tensor(1091)
# tensor(1092)
# tensor(1041)
# tensor(1092)
# tensor(1042)
# tensor(1041)
# tensor(1092)
# tensor(1093)
# tensor(1042)
# tensor(1093)
# tensor(1043)
# tensor(1042)
# tensor(1093)
# tensor(1094)
# tensor(1043)
# tensor(1094)
# tensor(1044)
# tensor(1043)
# tensor(1094)
# tensor(1095)
# tensor(1044)
# tensor(1095)
# tensor(1045)
# tensor(1044)
# tensor(1095)
# tensor(1096)
# tensor(1045)
# tensor(1096)
# tensor(1046)
# tensor(1045)
# tensor(1096)
# tensor(1097)
# tensor(1046)
# tensor(1097)
# tensor(1047)
# tensor(1046)
# tensor(1097)
# tensor(1098)
# tensor(1047)
# tensor(1098)
# tensor(1048)
# tensor(1047)
# tensor(1098)
# tensor(1099)
# tensor(1048)
# tensor(1099)
# tensor(1049)
# tensor(1048)
# tensor(1099)
# tensor(1050)
# tensor(1049)
# tensor(1050)
# tensor(1000)
# tensor(1049)
# tensor(1100)
# tensor(1101)
# tensor(1050)
# tensor(1101)
# tensor(1051)
# tensor(1050)
# tensor(1101)
# tensor(1102)
# tensor(1051)
# tensor(1102)
# tensor(1052)
# tensor(1051)
# tensor(1102)
# tensor(1103)
# tensor(1052)
# tensor(1103)
# tensor(1053)
# tensor(1052)
# tensor(1103)
# tensor(1104)
# tensor(1053)
# tensor(1104)
# tensor(1054)
# tensor(1053)
# tensor(1104)
# tensor(1105)
# tensor(1054)
# tensor(1105)
# tensor(1055)
# tensor(1054)
# tensor(1105)
# tensor(1106)
# tensor(1055)
# tensor(1106)
# tensor(1056)
# tensor(1055)
# tensor(1106)
# tensor(1107)
# tensor(1056)
# tensor(1107)
# tensor(1057)
# tensor(1056)
# tensor(1107)
# tensor(1108)
# tensor(1057)
# tensor(1108)
# tensor(1058)
# tensor(1057)
# tensor(1108)
# tensor(1109)
# tensor(1058)
# tensor(1109)
# tensor(1059)
# tensor(1058)
# tensor(1109)
# tensor(1110)
# tensor(1059)
# tensor(1110)
# tensor(1060)
# tensor(1059)
# tensor(1110)
# tensor(1111)
# tensor(1060)
# tensor(1111)
# tensor(1061)
# tensor(1060)
# tensor(1111)
# tensor(1112)
# tensor(1061)
# tensor(1112)
# tensor(1062)
# tensor(1061)
# tensor(1112)
# tensor(1113)
# tensor(1062)
# tensor(1113)
# tensor(1063)
# tensor(1062)
# tensor(1113)
# tensor(1114)
# tensor(1063)
# tensor(1114)
# tensor(1064)
# tensor(1063)
# tensor(1114)
# tensor(1115)
# tensor(1064)
# tensor(1115)
# tensor(1065)
# tensor(1064)
# tensor(1115)
# tensor(1116)
# tensor(1065)
# tensor(1116)
# tensor(1066)
# tensor(1065)
# tensor(1116)
# tensor(1117)
# tensor(1066)
# tensor(1117)
# tensor(1067)
# tensor(1066)
# tensor(1117)
# tensor(1118)
# tensor(1067)
# tensor(1118)
# tensor(1068)
# tensor(1067)
# tensor(1118)
# tensor(1119)
# tensor(1068)
# tensor(1119)
# tensor(1069)
# tensor(1068)
# tensor(1119)
# tensor(1120)
# tensor(1069)
# tensor(1120)
# tensor(1070)
# tensor(1069)
# tensor(1120)
# tensor(1121)
# tensor(1070)
# tensor(1121)
# tensor(1071)
# tensor(1070)
# tensor(1121)
# tensor(1122)
# tensor(1071)
# tensor(1122)
# tensor(1072)
# tensor(1071)
# tensor(1122)
# tensor(1123)
# tensor(1072)
# tensor(1123)
# tensor(1073)
# tensor(1072)
# tensor(1123)
# tensor(1124)
# tensor(1073)
# tensor(1124)
# tensor(1074)
# tensor(1073)
# tensor(1124)
# tensor(1125)
# tensor(1074)
# tensor(1125)
# tensor(1075)
# tensor(1074)
# tensor(1125)
# tensor(1126)
# tensor(1075)
# tensor(1126)
# tensor(1076)
# tensor(1075)
# tensor(1126)
# tensor(1127)
# tensor(1076)
# tensor(1127)
# tensor(1077)
# tensor(1076)
# tensor(1127)
# tensor(1128)
# tensor(1077)
# tensor(1128)
# tensor(1078)
# tensor(1077)
# tensor(1128)
# tensor(1129)
# tensor(1078)
# tensor(1129)
# tensor(1079)
# tensor(1078)
# tensor(1129)
# tensor(1130)
# tensor(1079)
# tensor(1130)
# tensor(1080)
# tensor(1079)
# tensor(1130)
# tensor(1131)
# tensor(1080)
# tensor(1131)
# tensor(1081)
# tensor(1080)
# tensor(1131)
# tensor(1132)
# tensor(1081)
# tensor(1132)
# tensor(1082)
# tensor(1081)
# tensor(1132)
# tensor(1133)
# tensor(1082)
# tensor(1133)
# tensor(1083)
# tensor(1082)
# tensor(1133)
# tensor(1134)
# tensor(1083)
# tensor(1134)
# tensor(1084)
# tensor(1083)
# tensor(1134)
# tensor(1135)
# tensor(1084)
# tensor(1135)
# tensor(1085)
# tensor(1084)
# tensor(1135)
# tensor(1136)
# tensor(1085)
# tensor(1136)
# tensor(1086)
# tensor(1085)
# tensor(1136)
# tensor(1137)
# tensor(1086)
# tensor(1137)
# tensor(1087)
# tensor(1086)
# tensor(1137)
# tensor(1138)
# tensor(1087)
# tensor(1138)
# tensor(1088)
# tensor(1087)
# tensor(1138)
# tensor(1139)
# tensor(1088)
# tensor(1139)
# tensor(1089)
# tensor(1088)
# tensor(1139)
# tensor(1140)
# tensor(1089)
# tensor(1140)
# tensor(1090)
# tensor(1089)
# tensor(1140)
# tensor(1141)
# tensor(1090)
# tensor(1141)
# tensor(1091)
# tensor(1090)
# tensor(1141)
# tensor(1142)
# tensor(1091)
# tensor(1142)
# tensor(1092)
# tensor(1091)
# tensor(1142)
# tensor(1143)
# tensor(1092)
# tensor(1143)
# tensor(1093)
# tensor(1092)
# tensor(1143)
# tensor(1144)
# tensor(1093)
# tensor(1144)
# tensor(1094)
# tensor(1093)
# tensor(1144)
# tensor(1145)
# tensor(1094)
# tensor(1145)
# tensor(1095)
# tensor(1094)
# tensor(1145)
# tensor(1146)
# tensor(1095)
# tensor(1146)
# tensor(1096)
# tensor(1095)
# tensor(1146)
# tensor(1147)
# tensor(1096)
# tensor(1147)
# tensor(1097)
# tensor(1096)
# tensor(1147)
# tensor(1148)
# tensor(1097)
# tensor(1148)
# tensor(1098)
# tensor(1097)
# tensor(1148)
# tensor(1149)
# tensor(1098)
# tensor(1149)
# tensor(1099)
# tensor(1098)
# tensor(1149)
# tensor(1100)
# tensor(1099)
# tensor(1100)
# tensor(1050)
# tensor(1099)
# tensor(1150)
# tensor(1151)
# tensor(1100)
# tensor(1151)
# tensor(1101)
# tensor(1100)
# tensor(1151)
# tensor(1152)
# tensor(1101)
# tensor(1152)
# tensor(1102)
# tensor(1101)
# tensor(1152)
# tensor(1153)
# tensor(1102)
# tensor(1153)
# tensor(1103)
# tensor(1102)
# tensor(1153)
# tensor(1154)
# tensor(1103)
# tensor(1154)
# tensor(1104)
# tensor(1103)
# tensor(1154)
# tensor(1155)
# tensor(1104)
# tensor(1155)
# tensor(1105)
# tensor(1104)
# tensor(1155)
# tensor(1156)
# tensor(1105)
# tensor(1156)
# tensor(1106)
# tensor(1105)
# tensor(1156)
# tensor(1157)
# tensor(1106)
# tensor(1157)
# tensor(1107)
# tensor(1106)
# tensor(1157)
# tensor(1158)
# tensor(1107)
# tensor(1158)
# tensor(1108)
# tensor(1107)
# tensor(1158)
# tensor(1159)
# tensor(1108)
# tensor(1159)
# tensor(1109)
# tensor(1108)
# tensor(1159)
# tensor(1160)
# tensor(1109)
# tensor(1160)
# tensor(1110)
# tensor(1109)
# tensor(1160)
# tensor(1161)
# tensor(1110)
# tensor(1161)
# tensor(1111)
# tensor(1110)
# tensor(1161)
# tensor(1162)
# tensor(1111)
# tensor(1162)
# tensor(1112)
# tensor(1111)
# tensor(1162)
# tensor(1163)
# tensor(1112)
# tensor(1163)
# tensor(1113)
# tensor(1112)
# tensor(1163)
# tensor(1164)
# tensor(1113)
# tensor(1164)
# tensor(1114)
# tensor(1113)
# tensor(1164)
# tensor(1165)
# tensor(1114)
# tensor(1165)
# tensor(1115)
# tensor(1114)
# tensor(1165)
# tensor(1166)
# tensor(1115)
# tensor(1166)
# tensor(1116)
# tensor(1115)
# tensor(1166)
# tensor(1167)
# tensor(1116)
# tensor(1167)
# tensor(1117)
# tensor(1116)
# tensor(1167)
# tensor(1168)
# tensor(1117)
# tensor(1168)
# tensor(1118)
# tensor(1117)
# tensor(1168)
# tensor(1169)
# tensor(1118)
# tensor(1169)
# tensor(1119)
# tensor(1118)
# tensor(1169)
# tensor(1170)
# tensor(1119)
# tensor(1170)
# tensor(1120)
# tensor(1119)
# tensor(1170)
# tensor(1171)
# tensor(1120)
# tensor(1171)
# tensor(1121)
# tensor(1120)
# tensor(1171)
# tensor(1172)
# tensor(1121)
# tensor(1172)
# tensor(1122)
# tensor(1121)
# tensor(1172)
# tensor(1173)
# tensor(1122)
# tensor(1173)
# tensor(1123)
# tensor(1122)
# tensor(1173)
# tensor(1174)
# tensor(1123)
# tensor(1174)
# tensor(1124)
# tensor(1123)
# tensor(1174)
# tensor(1175)
# tensor(1124)
# tensor(1175)
# tensor(1125)
# tensor(1124)
# tensor(1175)
# tensor(1176)
# tensor(1125)
# tensor(1176)
# tensor(1126)
# tensor(1125)
# tensor(1176)
# tensor(1177)
# tensor(1126)
# tensor(1177)
# tensor(1127)
# tensor(1126)
# tensor(1177)
# tensor(1178)
# tensor(1127)
# tensor(1178)
# tensor(1128)
# tensor(1127)
# tensor(1178)
# tensor(1179)
# tensor(1128)
# tensor(1179)
# tensor(1129)
# tensor(1128)
# tensor(1179)
# tensor(1180)
# tensor(1129)
# tensor(1180)
# tensor(1130)
# tensor(1129)
# tensor(1180)
# tensor(1181)
# tensor(1130)
# tensor(1181)
# tensor(1131)
# tensor(1130)
# tensor(1181)
# tensor(1182)
# tensor(1131)
# tensor(1182)
# tensor(1132)
# tensor(1131)
# tensor(1182)
# tensor(1183)
# tensor(1132)
# tensor(1183)
# tensor(1133)
# tensor(1132)
# tensor(1183)
# tensor(1184)
# tensor(1133)
# tensor(1184)
# tensor(1134)
# tensor(1133)
# tensor(1184)
# tensor(1185)
# tensor(1134)
# tensor(1185)
# tensor(1135)
# tensor(1134)
# tensor(1185)
# tensor(1186)
# tensor(1135)
# tensor(1186)
# tensor(1136)
# tensor(1135)
# tensor(1186)
# tensor(1187)
# tensor(1136)
# tensor(1187)
# tensor(1137)
# tensor(1136)
# tensor(1187)
# tensor(1188)
# tensor(1137)
# tensor(1188)
# tensor(1138)
# tensor(1137)
# tensor(1188)
# tensor(1189)
# tensor(1138)
# tensor(1189)
# tensor(1139)
# tensor(1138)
# tensor(1189)
# tensor(1190)
# tensor(1139)
# tensor(1190)
# tensor(1140)
# tensor(1139)
# tensor(1190)
# tensor(1191)
# tensor(1140)
# tensor(1191)
# tensor(1141)
# tensor(1140)
# tensor(1191)
# tensor(1192)
# tensor(1141)
# tensor(1192)
# tensor(1142)
# tensor(1141)
# tensor(1192)
# tensor(1193)
# tensor(1142)
# tensor(1193)
# tensor(1143)
# tensor(1142)
# tensor(1193)
# tensor(1194)
# tensor(1143)
# tensor(1194)
# tensor(1144)
# tensor(1143)
# tensor(1194)
# tensor(1195)
# tensor(1144)
# tensor(1195)
# tensor(1145)
# tensor(1144)
# tensor(1195)
# tensor(1196)
# tensor(1145)
# tensor(1196)
# tensor(1146)
# tensor(1145)
# tensor(1196)
# tensor(1197)
# tensor(1146)
# tensor(1197)
# tensor(1147)
# tensor(1146)
# tensor(1197)
# tensor(1198)
# tensor(1147)
# tensor(1198)
# tensor(1148)
# tensor(1147)
# tensor(1198)
# tensor(1199)
# tensor(1148)
# tensor(1199)
# tensor(1149)
# tensor(1148)
# tensor(1199)
# tensor(1150)
# tensor(1149)
# tensor(1150)
# tensor(1100)
# tensor(1149)
# tensor(1200)
# tensor(1201)
# tensor(1150)
# tensor(1201)
# tensor(1151)
# tensor(1150)
# tensor(1201)
# tensor(1202)
# tensor(1151)
# tensor(1202)
# tensor(1152)
# tensor(1151)
# tensor(1202)
# tensor(1203)
# tensor(1152)
# tensor(1203)
# tensor(1153)
# tensor(1152)
# tensor(1203)
# tensor(1204)
# tensor(1153)
# tensor(1204)
# tensor(1154)
# tensor(1153)
# tensor(1204)
# tensor(1205)
# tensor(1154)
# tensor(1205)
# tensor(1155)
# tensor(1154)
# tensor(1205)
# tensor(1206)
# tensor(1155)
# tensor(1206)
# tensor(1156)
# tensor(1155)
# tensor(1206)
# tensor(1207)
# tensor(1156)
# tensor(1207)
# tensor(1157)
# tensor(1156)
# tensor(1207)
# tensor(1208)
# tensor(1157)
# tensor(1208)
# tensor(1158)
# tensor(1157)
# tensor(1208)
# tensor(1209)
# tensor(1158)
# tensor(1209)
# tensor(1159)
# tensor(1158)
# tensor(1209)
# tensor(1210)
# tensor(1159)
# tensor(1210)
# tensor(1160)
# tensor(1159)
# tensor(1210)
# tensor(1211)
# tensor(1160)
# tensor(1211)
# tensor(1161)
# tensor(1160)
# tensor(1211)
# tensor(1212)
# tensor(1161)
# tensor(1212)
# tensor(1162)
# tensor(1161)
# tensor(1212)
# tensor(1213)
# tensor(1162)
# tensor(1213)
# tensor(1163)
# tensor(1162)
# tensor(1213)
# tensor(1214)
# tensor(1163)
# tensor(1214)
# tensor(1164)
# tensor(1163)
# tensor(1214)
# tensor(1215)
# tensor(1164)
# tensor(1215)
# tensor(1165)
# tensor(1164)
# tensor(1215)
# tensor(1216)
# tensor(1165)
# tensor(1216)
# tensor(1166)
# tensor(1165)
# tensor(1216)
# tensor(1217)
# tensor(1166)
# tensor(1217)
# tensor(1167)
# tensor(1166)
# tensor(1217)
# tensor(1218)
# tensor(1167)
# tensor(1218)
# tensor(1168)
# tensor(1167)
# tensor(1218)
# tensor(1219)
# tensor(1168)
# tensor(1219)
# tensor(1169)
# tensor(1168)
# tensor(1219)
# tensor(1220)
# tensor(1169)
# tensor(1220)
# tensor(1170)
# tensor(1169)
# tensor(1220)
# tensor(1221)
# tensor(1170)
# tensor(1221)
# tensor(1171)
# tensor(1170)
# tensor(1221)
# tensor(1222)
# tensor(1171)
# tensor(1222)
# tensor(1172)
# tensor(1171)
# tensor(1222)
# tensor(1223)
# tensor(1172)
# tensor(1223)
# tensor(1173)
# tensor(1172)
# tensor(1223)
# tensor(1224)
# tensor(1173)
# tensor(1224)
# tensor(1174)
# tensor(1173)
# tensor(1224)
# tensor(1225)
# tensor(1174)
# tensor(1225)
# tensor(1175)
# tensor(1174)
# tensor(1225)
# tensor(1226)
# tensor(1175)
# tensor(1226)
# tensor(1176)
# tensor(1175)
# tensor(1226)
# tensor(1227)
# tensor(1176)
# tensor(1227)
# tensor(1177)
# tensor(1176)
# tensor(1227)
# tensor(1228)
# tensor(1177)
# tensor(1228)
# tensor(1178)
# tensor(1177)
# tensor(1228)
# tensor(1229)
# tensor(1178)
# tensor(1229)
# tensor(1179)
# tensor(1178)
# tensor(1229)
# tensor(1230)
# tensor(1179)
# tensor(1230)
# tensor(1180)
# tensor(1179)
# tensor(1230)
# tensor(1231)
# tensor(1180)
# tensor(1231)
# tensor(1181)
# tensor(1180)
# tensor(1231)
# tensor(1232)
# tensor(1181)
# tensor(1232)
# tensor(1182)
# tensor(1181)
# tensor(1232)
# tensor(1233)
# tensor(1182)
# tensor(1233)
# tensor(1183)
# tensor(1182)
# tensor(1233)
# tensor(1234)
# tensor(1183)
# tensor(1234)
# tensor(1184)
# tensor(1183)
# tensor(1234)
# tensor(1235)
# tensor(1184)
# tensor(1235)
# tensor(1185)
# tensor(1184)
# tensor(1235)
# tensor(1236)
# tensor(1185)
# tensor(1236)
# tensor(1186)
# tensor(1185)
# tensor(1236)
# tensor(1237)
# tensor(1186)
# tensor(1237)
# tensor(1187)
# tensor(1186)
# tensor(1237)
# tensor(1238)
# tensor(1187)
# tensor(1238)
# tensor(1188)
# tensor(1187)
# tensor(1238)
# tensor(1239)
# tensor(1188)
# tensor(1239)
# tensor(1189)
# tensor(1188)
# tensor(1239)
# tensor(1240)
# tensor(1189)
# tensor(1240)
# tensor(1190)
# tensor(1189)
# tensor(1240)
# tensor(1241)
# tensor(1190)
# tensor(1241)
# tensor(1191)
# tensor(1190)
# tensor(1241)
# tensor(1242)
# tensor(1191)
# tensor(1242)
# tensor(1192)
# tensor(1191)
# tensor(1242)
# tensor(1243)
# tensor(1192)
# tensor(1243)
# tensor(1193)
# tensor(1192)
# tensor(1243)
# tensor(1244)
# tensor(1193)
# tensor(1244)
# tensor(1194)
# tensor(1193)
# tensor(1244)
# tensor(1245)
# tensor(1194)
# tensor(1245)
# tensor(1195)
# tensor(1194)
# tensor(1245)
# tensor(1246)
# tensor(1195)
# tensor(1246)
# tensor(1196)
# tensor(1195)
# tensor(1246)
# tensor(1247)
# tensor(1196)
# tensor(1247)
# tensor(1197)
# tensor(1196)
# tensor(1247)
# tensor(1248)
# tensor(1197)
# tensor(1248)
# tensor(1198)
# tensor(1197)
# tensor(1248)
# tensor(1249)
# tensor(1198)
# tensor(1249)
# tensor(1199)
# tensor(1198)
# tensor(1249)
# tensor(1200)
# tensor(1199)
# tensor(1200)
# tensor(1150)
# tensor(1199)
# tensor(1249)
# tensor(1201)
# tensor(1200)
# tensor(1248)
# tensor(1201)
# tensor(1249)
# tensor(1248)
# tensor(1202)
# tensor(1201)
# tensor(1247)
# tensor(1202)
# tensor(1248)
# tensor(1247)
# tensor(1203)
# tensor(1202)
# tensor(1246)
# tensor(1203)
# tensor(1247)
# tensor(1246)
# tensor(1204)
# tensor(1203)
# tensor(1245)
# tensor(1204)
# tensor(1246)
# tensor(1245)
# tensor(1205)
# tensor(1204)
# tensor(1244)
# tensor(1205)
# tensor(1245)
# tensor(1244)
# tensor(1206)
# tensor(1205)
# tensor(1243)
# tensor(1206)
# tensor(1244)
# tensor(1243)
# tensor(1207)
# tensor(1206)
# tensor(1242)
# tensor(1207)
# tensor(1243)
# tensor(1242)
# tensor(1208)
# tensor(1207)
# tensor(1241)
# tensor(1208)
# tensor(1242)
# tensor(1241)
# tensor(1209)
# tensor(1208)
# tensor(1240)
# tensor(1209)
# tensor(1241)
# tensor(1240)
# tensor(1210)
# tensor(1209)
# tensor(1239)
# tensor(1210)
# tensor(1240)
# tensor(1239)
# tensor(1211)
# tensor(1210)
# tensor(1238)
# tensor(1211)
# tensor(1239)
# tensor(1238)
# tensor(1212)
# tensor(1211)
# tensor(1237)
# tensor(1212)
# tensor(1238)
# tensor(1237)
# tensor(1213)
# tensor(1212)
# tensor(1236)
# tensor(1213)
# tensor(1237)
# tensor(1236)
# tensor(1214)
# tensor(1213)
# tensor(1235)
# tensor(1214)
# tensor(1236)
# tensor(1235)
# tensor(1215)
# tensor(1214)
# tensor(1234)
# tensor(1215)
# tensor(1235)
# tensor(1234)
# tensor(1216)
# tensor(1215)
# tensor(1233)
# tensor(1216)
# tensor(1234)
# tensor(1233)
# tensor(1217)
# tensor(1216)
# tensor(1232)
# tensor(1217)
# tensor(1233)
# tensor(1232)
# tensor(1218)
# tensor(1217)
# tensor(1231)
# tensor(1218)
# tensor(1232)
# tensor(1231)
# tensor(1219)
# tensor(1218)
# tensor(1230)
# tensor(1219)
# tensor(1231)
# tensor(1230)
# tensor(1220)
# tensor(1219)
# tensor(1229)
# tensor(1220)
# tensor(1230)
# tensor(1229)
# tensor(1221)
# tensor(1220)
# tensor(1228)
# tensor(1221)
# tensor(1229)
# tensor(1228)
# tensor(1222)
# tensor(1221)
# tensor(1227)
# tensor(1222)
# tensor(1228)
# tensor(1227)
# tensor(1223)
# tensor(1222)
# tensor(1226)
# tensor(1223)
# tensor(1227)
# tensor(1226)
# tensor(1224)
# tensor(1223)
# tensor(1224)
# tensor(1226)
# tensor(1225)
# File saved!
